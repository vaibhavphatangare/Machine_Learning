# %%
# Import necessary libraries
from sklearn.linear_model import Ridge, LinearRegression, LogisticRegression
from sklearn.metrics import accuracy_score,log_loss
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import GridSearchCV,KFold
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.tree import DecisionTreeClassifier,DecisionTreeRegressor
from sklearn.ensemble import VotingClassifier, BaggingClassifier,BaggingRegressor
from sklearn.neighbors import *
from sklearn.svm import SVC
from sklearn.pipeline import *
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import warnings
import os

warnings.simplefilter('ignore')

os.chdir('D:\Datasets')

conc = pd.read_csv('Concrete_Data.csv')
conc
# Out:
#       Cement  Blast    Fly  Water  Superplasticizer  Coarse   Fine  Age  \
# 0      540.0    0.0    0.0  162.0               2.5  1040.0  676.0   28
# 1      540.0    0.0    0.0  162.0               2.5  1055.0  676.0   28
# 2      332.5  142.5    0.0  228.0               0.0   932.0  594.0  270
# 3      332.5  142.5    0.0  228.0               0.0   932.0  594.0  365
# 4      198.6  132.4    0.0  192.0               0.0   978.4  825.5  360
# ...      ...    ...    ...    ...               ...     ...    ...  ...
# 1025   276.4  116.0   90.3  179.6               8.9   870.1  768.3   28
# 1026   322.2    0.0  115.6  196.0              10.4   817.9  813.4   28
# 1027   148.5  139.4  108.6  192.7               6.1   892.4  780.0   28
# 1028   159.1  186.7    0.0  175.6              11.3   989.6  788.9   28
# 1029   260.9  100.5   78.3  200.6               8.6   864.5  761.5   28
#
#       Strength
# 0        79.99
# 1        61.89
# 2        40.27
# 3        41.05
# 4        44.30
# ...        ...
# 1025     44.28
# 1026     31.18
# 1027     23.70
# 1028     32.77
# 1029     32.40
#
# [1030 rows x 9 columns]

# %%
x= conc.drop('Strength',axis=1)
y=conc['Strength']

# %%
# Create a K-Fold cross-validation object with 5 splits, shuffling the data, and a random state of 24
kfold = KFold(n_splits=5, shuffle=True, random_state=24)

# Create a Decision Tree Regressor
dtr = DecisionTreeRegressor()

# Create a Ridge Regression model
ridge = Ridge()

# Create a Linear Regression model
lr = LinearRegression()

# Create a Bagging Regressor using Linear Regression as the base estimator
# Set the number of estimators to 15 and enable out-of-bag (OOB) score calculation
bagg = BaggingRegressor(estimator=lr, n_estimators=15, random_state=24, oob_score=True)

# Define the parameter grid for the Bagging Regressor
params = {
    'estimator': [lr, ridge, dtr],
    'n_estimators': [10, 15]
}

# Create a GridSearchCV object to perform cross-validation and hyperparameter tuning
# Use the Bagging Regressor as the estimator, the parameter grid defined above, the K-Fold cross-validation,
# set the verbosity to 3
gcv = GridSearchCV(bagg, param_grid=params, cv=kfold, verbose=3)

# Fit the GridSearchCV object to the entire dataset (x and y)
gcv.fit(x, y)

# Print the best parameters found by the GridSearchCV
print("Best Parameters:", gcv.best_params_)

# Print the best score found by the GridSearchCV
print("Best Score:", gcv.best_score_)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV 1/5] END estimator=LinearRegression(), n_estimators=10;, score=0.539 total time=   0.0s
# [CV 2/5] END estimator=LinearRegression(), n_estimators=10;, score=0.623 total time=   0.0s
# [CV 3/5] END estimator=LinearRegression(), n_estimators=10;, score=0.635 total time=   0.0s
# [CV 4/5] END estimator=LinearRegression(), n_estimators=10;, score=0.599 total time=   0.0s
# [CV 5/5] END estimator=LinearRegression(), n_estimators=10;, score=0.636 total time=   0.0s
# [CV 1/5] END estimator=LinearRegression(), n_estimators=15;, score=0.542 total time=   0.0s
# [CV 2/5] END estimator=LinearRegression(), n_estimators=15;, score=0.624 total time=   0.0s
# [CV 3/5] END estimator=LinearRegression(), n_estimators=15;, score=0.633 total time=   0.0s
# [CV 4/5] END estimator=LinearRegression(), n_estimators=15;, score=0.600 total time=   0.0s
# [CV 5/5] END estimator=LinearRegression(), n_estimators=15;, score=0.635 total time=   0.0s
# [CV 1/5] END estimator=Ridge(), n_estimators=10;, score=0.539 total time=   0.0s
# [CV 2/5] END estimator=Ridge(), n_estimators=10;, score=0.623 total time=   0.0s
# [CV 3/5] END estimator=Ridge(), n_estimators=10;, score=0.635 total time=   0.0s
# [CV 4/5] END estimator=Ridge(), n_estimators=10;, score=0.599 total time=   0.0s
# [CV 5/5] END estimator=Ridge(), n_estimators=10;, score=0.636 total time=   0.0s
# [CV 1/5] END estimator=Ridge(), n_estimators=15;, score=0.542 total time=   0.0s
# [CV 2/5] END estimator=Ridge(), n_estimators=15;, score=0.624 total time=   0.0s
# [CV 3/5] END estimator=Ridge(), n_estimators=15;, score=0.633 total time=   0.0s
# [CV 4/5] END estimator=Ridge(), n_estimators=15;, score=0.600 total time=   0.0s
# [CV 5/5] END estimator=Ridge(), n_estimators=15;, score=0.635 total time=   0.0s
# [CV 1/5] END estimator=DecisionTreeRegressor(), n_estimators=10;, score=0.904 total time=   0.0s
# [CV 2/5] END estimator=DecisionTreeRegressor(), n_estimators=10;, score=0.872 total time=   0.0s
# [CV 3/5] END estimator=DecisionTreeRegressor(), n_estimators=10;, score=0.923 total time=   0.0s
# [CV 4/5] END estimator=DecisionTreeRegressor(), n_estimators=10;, score=0.883 total time=   0.0s
# [CV 5/5] END estimator=DecisionTreeRegressor(), n_estimators=10;, score=0.913 total time=   0.0s
# [CV 1/5] END estimator=DecisionTreeRegressor(), n_estimators=15;, score=0.916 total time=   0.0s
# [CV 2/5] END estimator=DecisionTreeRegressor(), n_estimators=15;, score=0.878 total time=   0.0s
# [CV 3/5] END estimator=DecisionTreeRegressor(), n_estimators=15;, score=0.926 total time=   0.0s
# [CV 4/5] END estimator=DecisionTreeRegressor(), n_estimators=15;, score=0.887 total time=   0.0s
# [CV 5/5] END estimator=DecisionTreeRegressor(), n_estimators=15;, score=0.916 total time=   0.0s
# Best Parameters: {'estimator': DecisionTreeRegressor(), 'n_estimators': 15}
# Best Score: 0.904671474957022

# %%
# Create a Bagging Regressor using Decision Tree Regressor as the base estimator
# Set the random state to 24
bagg = BaggingRegressor(estimator=dtr, random_state=24)

# Print the parameters of the Bagging Regressor
print(bagg.get_params())
# Out:
# {'base_estimator': 'deprecated', 'bootstrap': True, 'bootstrap_features': False, 'estimator__ccp_alpha': 0.0, 'estimator__criterion': 'squared_error', 'estimator__max_depth': None, 'estimator__max_features': None, 'estimator__max_leaf_nodes': None, 'estimator__min_impurity_decrease': 0.0, 'estimator__min_samples_leaf': 1, 'estimator__min_samples_split': 2, 'estimator__min_weight_fraction_leaf': 0.0, 'estimator__random_state': None, 'estimator__splitter': 'best', 'estimator': DecisionTreeRegressor(), 'max_features': 1.0, 'max_samples': 1.0, 'n_estimators': 10, 'n_jobs': None, 'oob_score': False, 'random_state': 24, 'verbose': 0, 'warm_start': False}

# %% [markdown]
# # hyperparameter tuning

# %%
# Define the parameter grid for the Bagging Regressor
params = {
    'estimator__max_depth': [None, 3, 5],
    'estimator__min_samples_leaf': [1, 5, 10],
    'estimator__min_samples_split': [2, 5, 10],
    'n_estimators': [15, 30, 50]
}

# Create a GridSearchCV object to perform cross-validation and hyperparameter tuning
# Use the Bagging Regressor as the estimator, the parameter grid defined above, the K-Fold cross-validation,
# set the verbosity to 3
gcv_s = GridSearchCV(bagg, param_grid=params, cv=kfold, verbose=3)

# Fit the GridSearchCV object to the entire dataset (x and y)
gcv_s.fit(x, y)

# Print the best parameters found by the GridSearchCV
print("Best Parameters:", gcv_s.best_params_)

# Print the best score found by the GridSearchCV
print("Best Score:", gcv_s.best_score_)
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# [CV 1/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=15;, score=0.916 total time=   0.0s
# [CV 2/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=15;, score=0.878 total time=   0.0s
# [CV 3/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=15;, score=0.926 total time=   0.0s
# [CV 4/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=15;, score=0.887 total time=   0.0s
# [CV 5/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=15;, score=0.916 total time=   0.0s
# [CV 1/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=30;, score=0.917 total time=   0.1s
# [CV 2/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=30;, score=0.880 total time=   0.1s
# [CV 3/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=30;, score=0.925 total time=   0.0s
# [CV 4/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=30;, score=0.899 total time=   0.1s
# [CV 5/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=30;, score=0.920 total time=   0.0s
# [CV 1/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=50;, score=0.920 total time=   0.2s
# [CV 2/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=50;, score=0.880 total time=   0.2s
# [CV 3/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=50;, score=0.924 total time=   0.2s
# [CV 4/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=50;, score=0.898 total time=   0.2s
# [CV 5/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=50;, score=0.921 total time=   0.2s
# [CV 1/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=5, n_estimators=15;, score=0.914 total time=   0.0s
# [CV 2/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=5, n_estimators=15;, score=0.874 total time=   0.0s
# [CV 3/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=5, n_estimators=15;, score=0.924 total time=   0.0s
# [CV 4/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=5, n_estimators=15;, score=0.881 total time=   0.0s
# [CV 5/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=5, n_estimators=15;, score=0.913 total time=   0.0s
# [CV 1/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=5, n_estimators=30;, score=0.916 total time=   0.0s
# [CV 2/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=5, n_estimators=30;, score=0.879 total time=   0.0s
# [CV 3/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=5, n_estimators=30;, score=0.924 total time=   0.0s
# [CV 4/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=5, n_estimators=30;, score=0.894 total time=   0.1s
# [CV 5/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=5, n_estimators=30;, score=0.917 total time=   0.0s
# [CV 1/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=5, n_estimators=50;, score=0.919 total time=   0.1s
# [CV 2/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=5, n_estimators=50;, score=0.878 total time=   0.1s
# [CV 3/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=5, n_estimators=50;, score=0.922 total time=   0.1s
# [CV 4/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=5, n_estimators=50;, score=0.894 total time=   0.1s
# [CV 5/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=5, n_estimators=50;, score=0.918 total time=   0.1s
# [CV 1/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=15;, score=0.897 total time=   0.0s
# [CV 2/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=15;, score=0.863 total time=   0.0s
# [CV 3/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=15;, score=0.920 total time=   0.0s
# [CV 4/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=15;, score=0.871 total time=   0.0s
# [CV 5/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=15;, score=0.902 total time=   0.0s
# [CV 1/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=30;, score=0.903 total time=   0.0s
# [CV 2/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=30;, score=0.868 total time=   0.0s
# [CV 3/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=30;, score=0.918 total time=   0.0s
# [CV 4/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=30;, score=0.882 total time=   0.0s
# [CV 5/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=30;, score=0.904 total time=   0.0s
# [CV 1/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=50;, score=0.906 total time=   0.1s
# [CV 2/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=50;, score=0.868 total time=   0.1s
# [CV 3/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=50;, score=0.916 total time=   0.1s
# [CV 4/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=50;, score=0.882 total time=   0.1s
# [CV 5/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=50;, score=0.906 total time=   0.1s
# [CV 1/5] END estimator__max_depth=None, estimator__min_samples_leaf=5, estimator__min_samples_split=2, n_estimators=15;, score=0.886 total time=   0.0s
# [CV 2/5] END estimator__max_depth=None, estimator__min_samples_leaf=5, estimator__min_samples_split=2, n_estimators=15;, score=0.842 total time=   0.0s
# [CV 3/5] END estimator__max_depth=None, estimator__min_samples_leaf=5, estimator__min_samples_split=2, n_estimators=15;, score=0.905 total time=   0.0s
# [CV 4/5] END estimator__max_depth=None, estimator__min_samples_leaf=5, estimator__min_samples_split=2, n_estimators=15;, score=0.853 total time=   0.0s
# [CV 5/5] END estimator__max_depth=None, estimator__min_samples_leaf=5, estimator__min_samples_split=2, n_estimators=15;, score=0.887 total time=   0.0s
# [CV 1/5] END estimator__max_depth=None, estimator__min_samples_leaf=5, estimator__min_samples_split=2, n_estimators=30;, score=0.888 total time=   0.0s
# [CV 2/5] END estimator__max_depth=None, estimator__min_samples_leaf=5, estimator__min_samples_split=2, n_estimators=30;, score=0.845 total time=   0.0s
# [CV 3/5] END estimator__max_depth=None, estimator__min_samples_leaf=5, estimator__min_samples_split=2, n_estimators=30;, score=0.907 total time=   0.0s
# [CV 4/5] END estimator__max_depth=None, estimator__min_samples_leaf=5, estimator__min_samples_split=2, n_estimators=30;, score=0.863 total time=   0.0s
# [CV 5/5] END estimator__max_depth=None, estimator__min_samples_leaf=5, estimator__min_samples_split=2, n_estimators=30;, score=0.885 total time=   0.0s
# [CV 1/5] END estimator__max_depth=None, estimator__min_samples_leaf=5, estimator__min_samples_split=2, n_estimators=50;, score=0.891 total time=   0.1s
# [CV 2/5] END estimator__max_depth=None, estimator__min_samples_leaf=5, estimator__min_samples_split=2, n_estimators=50;, score=0.849 total time=   0.1s
# [CV 3/5] END estimator__max_depth=None, estimator__min_samples_leaf=5, estimator__min_samples_split=2, n_estimators=50;, score=0.907 total time=   0.1s
# [CV 4/5] END estimator__max_depth=None, estimator__min_samples_leaf=5, estimator__min_samples_split=2, n_estimators=50;, score=0.865 total time=   0.1s
# [CV 5/5] END estimator__max_depth=None, estimator__min_samples_leaf=5, estimator__min_samples_split=2, n_estimators=50;, score=0.887 total time=   0.1s
# [CV 1/5] END estimator__max_depth=None, estimator__min_samples_leaf=5, estimator__min_samples_split=5, n_estimators=15;, score=0.886 total time=   0.0s
# [CV 2/5] END estimator__max_depth=None, estimator__min_samples_leaf=5, estimator__min_samples_split=5, n_estimators=15;, score=0.842 total time=   0.0s
# [CV 3/5] END estimator__max_depth=None, estimator__min_samples_leaf=5, estimator__min_samples_split=5, n_estimators=15;, score=0.905 total time=   0.0s
# [CV 4/5] END estimator__max_depth=None, estimator__min_samples_leaf=5, estimator__min_samples_split=5, n_estimators=15;, score=0.853 total time=   0.0s
# [CV 5/5] END estimator__max_depth=None, estimator__min_samples_leaf=5, estimator__min_samples_split=5, n_estimators=15;, score=0.887 total time=   0.0s
# [CV 1/5] END estimator__max_depth=None, estimator__min_samples_leaf=5, estimator__min_samples_split=5, n_estimators=30;, score=0.888 total time=   0.0s
# [CV 2/5] END estimator__max_depth=None, estimator__min_samples_leaf=5, estimator__min_samples_split=5, n_estimators=30;, score=0.845 total time=   0.0s
# [CV 3/5] END estimator__max_depth=None, estimator__min_samples_leaf=5, estimator__min_samples_split=5, n_estimators=30;, score=0.907 total time=   0.0s
# [CV 4/5] END estimator__max_depth=None, estimator__min_samples_leaf=5, estimator__min_samples_split=5, n_estimators=30;, score=0.863 total time=   0.0s
# [CV 5/5] END estimator__max_depth=None, estimator__min_samples_leaf=5, estimator__min_samples_split=5, n_estimators=30;, score=0.885 total time=   0.0s
# [CV 1/5] END estimator__max_depth=None, estimator__min_samples_leaf=5, estimator__min_samples_split=5, n_estimators=50;, score=0.891 total time=   0.1s
# [CV 2/5] END estimator__max_depth=None, estimator__min_samples_leaf=5, estimator__min_samples_split=5, n_estimators=50;, score=0.849 total time=   0.1s
# [CV 3/5] END estimator__max_depth=None, estimator__min_samples_leaf=5, estimator__min_samples_split=5, n_estimators=50;, score=0.907 total time=   0.1s
# [CV 4/5] END estimator__max_depth=None, estimator__min_samples_leaf=5, estimator__min_samples_split=5, n_estimators=50;, score=0.865 total time=   0.1s
# [CV 5/5] END estimator__max_depth=None, estimator__min_samples_leaf=5, estimator__min_samples_split=5, n_estimators=50;, score=0.887 total time=   0.1s
# [CV 1/5] END estimator__max_depth=None, estimator__min_samples_leaf=5, estimator__min_samples_split=10, n_estimators=15;, score=0.886 total time=   0.0s
# [CV 2/5] END estimator__max_depth=None, estimator__min_samples_leaf=5, estimator__min_samples_split=10, n_estimators=15;, score=0.842 total time=   0.0s
# [CV 3/5] END estimator__max_depth=None, estimator__min_samples_leaf=5, estimator__min_samples_split=10, n_estimators=15;, score=0.905 total time=   0.0s
# [CV 4/5] END estimator__max_depth=None, estimator__min_samples_leaf=5, estimator__min_samples_split=10, n_estimators=15;, score=0.853 total time=   0.0s
# [CV 5/5] END estimator__max_depth=None, estimator__min_samples_leaf=5, estimator__min_samples_split=10, n_estimators=15;, score=0.887 total time=   0.0s
# [CV 1/5] END estimator__max_depth=None, estimator__min_samples_leaf=5, estimator__min_samples_split=10, n_estimators=30;, score=0.888 total time=   0.0s
# [CV 2/5] END estimator__max_depth=None, estimator__min_samples_leaf=5, estimator__min_samples_split=10, n_estimators=30;, score=0.845 total time=   0.0s
# [CV 3/5] END estimator__max_depth=None, estimator__min_samples_leaf=5, estimator__min_samples_split=10, n_estimators=30;, score=0.907 total time=   0.0s
# [CV 4/5] END estimator__max_depth=None, estimator__min_samples_leaf=5, estimator__min_samples_split=10, n_estimators=30;, score=0.863 total time=   0.0s
# [CV 5/5] END estimator__max_depth=None, estimator__min_samples_leaf=5, estimator__min_samples_split=10, n_estimators=30;, score=0.885 total time=   0.0s
# [CV 1/5] END estimator__max_depth=None, estimator__min_samples_leaf=5, estimator__min_samples_split=10, n_estimators=50;, score=0.891 total time=   0.1s
# [CV 2/5] END estimator__max_depth=None, estimator__min_samples_leaf=5, estimator__min_samples_split=10, n_estimators=50;, score=0.849 total time=   0.1s
# [CV 3/5] END estimator__max_depth=None, estimator__min_samples_leaf=5, estimator__min_samples_split=10, n_estimators=50;, score=0.907 total time=   0.1s
# [CV 4/5] END estimator__max_depth=None, estimator__min_samples_leaf=5, estimator__min_samples_split=10, n_estimators=50;, score=0.865 total time=   0.1s
# [CV 5/5] END estimator__max_depth=None, estimator__min_samples_leaf=5, estimator__min_samples_split=10, n_estimators=50;, score=0.887 total time=   0.1s
# [CV 1/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=15;, score=0.848 total time=   0.0s
# [CV 2/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=15;, score=0.802 total time=   0.0s
# [CV 3/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=15;, score=0.889 total time=   0.0s
# [CV 4/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=15;, score=0.820 total time=   0.0s
# [CV 5/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=15;, score=0.856 total time=   0.0s
# [CV 1/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=30;, score=0.854 total time=   0.0s
# [CV 2/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=30;, score=0.808 total time=   0.0s
# [CV 3/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=30;, score=0.889 total time=   0.0s
# [CV 4/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=30;, score=0.830 total time=   0.0s
# [CV 5/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=30;, score=0.852 total time=   0.0s
# [CV 1/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=50;, score=0.857 total time=   0.1s
# [CV 2/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=50;, score=0.811 total time=   0.1s
# [CV 3/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=50;, score=0.888 total time=   0.1s
# [CV 4/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=50;, score=0.834 total time=   0.1s
# [CV 5/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=50;, score=0.855 total time=   0.0s
# [CV 1/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=5, n_estimators=15;, score=0.848 total time=   0.0s
# [CV 2/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=5, n_estimators=15;, score=0.802 total time=   0.0s
# [CV 3/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=5, n_estimators=15;, score=0.889 total time=   0.0s
# [CV 4/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=5, n_estimators=15;, score=0.820 total time=   0.0s
# [CV 5/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=5, n_estimators=15;, score=0.856 total time=   0.0s
# [CV 1/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=5, n_estimators=30;, score=0.854 total time=   0.0s
# [CV 2/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=5, n_estimators=30;, score=0.808 total time=   0.0s
# [CV 3/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=5, n_estimators=30;, score=0.889 total time=   0.0s
# [CV 4/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=5, n_estimators=30;, score=0.830 total time=   0.0s
# [CV 5/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=5, n_estimators=30;, score=0.852 total time=   0.0s
# [CV 1/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=5, n_estimators=50;, score=0.857 total time=   0.1s
# [CV 2/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=5, n_estimators=50;, score=0.811 total time=   0.0s
# [CV 3/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=5, n_estimators=50;, score=0.888 total time=   0.0s
# [CV 4/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=5, n_estimators=50;, score=0.834 total time=   0.1s
# [CV 5/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=5, n_estimators=50;, score=0.855 total time=   0.0s
# [CV 1/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=15;, score=0.848 total time=   0.0s
# [CV 2/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=15;, score=0.802 total time=   0.0s
# [CV 3/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=15;, score=0.889 total time=   0.0s
# [CV 4/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=15;, score=0.820 total time=   0.0s
# [CV 5/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=15;, score=0.856 total time=   0.0s
# [CV 1/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=30;, score=0.854 total time=   0.0s
# [CV 2/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=30;, score=0.808 total time=   0.0s
# [CV 3/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=30;, score=0.889 total time=   0.0s
# [CV 4/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=30;, score=0.830 total time=   0.0s
# [CV 5/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=30;, score=0.852 total time=   0.0s
# [CV 1/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=50;, score=0.857 total time=   0.0s
# [CV 2/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=50;, score=0.811 total time=   0.1s
# [CV 3/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=50;, score=0.888 total time=   0.1s
# [CV 4/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=50;, score=0.834 total time=   0.1s
# [CV 5/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=50;, score=0.855 total time=   0.1s
# [CV 1/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=15;, score=0.697 total time=   0.0s
# [CV 2/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=15;, score=0.622 total time=   0.0s
# [CV 3/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=15;, score=0.722 total time=   0.0s
# [CV 4/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=15;, score=0.621 total time=   0.0s
# [CV 5/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=15;, score=0.681 total time=   0.0s
# [CV 1/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=30;, score=0.708 total time=   0.0s
# [CV 2/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=30;, score=0.634 total time=   0.0s
# [CV 3/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=30;, score=0.714 total time=   0.0s
# [CV 4/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=30;, score=0.622 total time=   0.0s
# [CV 5/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=30;, score=0.677 total time=   0.0s
# [CV 1/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=50;, score=0.718 total time=   0.0s
# [CV 2/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=50;, score=0.635 total time=   0.0s
# [CV 3/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=50;, score=0.711 total time=   0.0s
# [CV 4/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=50;, score=0.634 total time=   0.0s
# [CV 5/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=50;, score=0.673 total time=   0.0s
# [CV 1/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=5, n_estimators=15;, score=0.697 total time=   0.0s
# [CV 2/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=5, n_estimators=15;, score=0.622 total time=   0.0s
# [CV 3/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=5, n_estimators=15;, score=0.722 total time=   0.0s
# [CV 4/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=5, n_estimators=15;, score=0.621 total time=   0.0s
# [CV 5/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=5, n_estimators=15;, score=0.681 total time=   0.0s
# [CV 1/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=5, n_estimators=30;, score=0.708 total time=   0.0s
# [CV 2/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=5, n_estimators=30;, score=0.634 total time=   0.0s
# [CV 3/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=5, n_estimators=30;, score=0.714 total time=   0.0s
# [CV 4/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=5, n_estimators=30;, score=0.622 total time=   0.0s
# [CV 5/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=5, n_estimators=30;, score=0.677 total time=   0.0s
# [CV 1/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=5, n_estimators=50;, score=0.718 total time=   0.0s
# [CV 2/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=5, n_estimators=50;, score=0.635 total time=   0.0s
# [CV 3/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=5, n_estimators=50;, score=0.711 total time=   0.0s
# [CV 4/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=5, n_estimators=50;, score=0.634 total time=   0.0s
# [CV 5/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=5, n_estimators=50;, score=0.673 total time=   0.0s
# [CV 1/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=15;, score=0.697 total time=   0.0s
# [CV 2/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=15;, score=0.622 total time=   0.0s
# [CV 3/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=15;, score=0.722 total time=   0.0s
# [CV 4/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=15;, score=0.621 total time=   0.0s
# [CV 5/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=15;, score=0.681 total time=   0.0s
# [CV 1/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=30;, score=0.708 total time=   0.0s
# [CV 2/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=30;, score=0.634 total time=   0.0s
# [CV 3/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=30;, score=0.714 total time=   0.0s
# [CV 4/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=30;, score=0.622 total time=   0.0s
# [CV 5/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=30;, score=0.677 total time=   0.0s
# [CV 1/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=50;, score=0.718 total time=   0.0s
# [CV 2/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=50;, score=0.635 total time=   0.0s
# [CV 3/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=50;, score=0.711 total time=   0.0s
# [CV 4/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=50;, score=0.634 total time=   0.0s
# [CV 5/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=50;, score=0.673 total time=   0.0s
# [CV 1/5] END estimator__max_depth=3, estimator__min_samples_leaf=5, estimator__min_samples_split=2, n_estimators=15;, score=0.696 total time=   0.0s
# [CV 2/5] END estimator__max_depth=3, estimator__min_samples_leaf=5, estimator__min_samples_split=2, n_estimators=15;, score=0.622 total time=   0.0s
# [CV 3/5] END estimator__max_depth=3, estimator__min_samples_leaf=5, estimator__min_samples_split=2, n_estimators=15;, score=0.722 total time=   0.0s
# [CV 4/5] END estimator__max_depth=3, estimator__min_samples_leaf=5, estimator__min_samples_split=2, n_estimators=15;, score=0.621 total time=   0.0s
# [CV 5/5] END estimator__max_depth=3, estimator__min_samples_leaf=5, estimator__min_samples_split=2, n_estimators=15;, score=0.679 total time=   0.0s
# [CV 1/5] END estimator__max_depth=3, estimator__min_samples_leaf=5, estimator__min_samples_split=2, n_estimators=30;, score=0.707 total time=   0.0s
# [CV 2/5] END estimator__max_depth=3, estimator__min_samples_leaf=5, estimator__min_samples_split=2, n_estimators=30;, score=0.634 total time=   0.0s
# [CV 3/5] END estimator__max_depth=3, estimator__min_samples_leaf=5, estimator__min_samples_split=2, n_estimators=30;, score=0.714 total time=   0.0s
# [CV 4/5] END estimator__max_depth=3, estimator__min_samples_leaf=5, estimator__min_samples_split=2, n_estimators=30;, score=0.621 total time=   0.0s
# [CV 5/5] END estimator__max_depth=3, estimator__min_samples_leaf=5, estimator__min_samples_split=2, n_estimators=30;, score=0.676 total time=   0.0s
# [CV 1/5] END estimator__max_depth=3, estimator__min_samples_leaf=5, estimator__min_samples_split=2, n_estimators=50;, score=0.718 total time=   0.0s
# [CV 2/5] END estimator__max_depth=3, estimator__min_samples_leaf=5, estimator__min_samples_split=2, n_estimators=50;, score=0.634 total time=   0.0s
# [CV 3/5] END estimator__max_depth=3, estimator__min_samples_leaf=5, estimator__min_samples_split=2, n_estimators=50;, score=0.711 total time=   0.0s
# [CV 4/5] END estimator__max_depth=3, estimator__min_samples_leaf=5, estimator__min_samples_split=2, n_estimators=50;, score=0.634 total time=   0.0s
# [CV 5/5] END estimator__max_depth=3, estimator__min_samples_leaf=5, estimator__min_samples_split=2, n_estimators=50;, score=0.673 total time=   0.0s
# [CV 1/5] END estimator__max_depth=3, estimator__min_samples_leaf=5, estimator__min_samples_split=5, n_estimators=15;, score=0.696 total time=   0.0s
# [CV 2/5] END estimator__max_depth=3, estimator__min_samples_leaf=5, estimator__min_samples_split=5, n_estimators=15;, score=0.622 total time=   0.0s
# [CV 3/5] END estimator__max_depth=3, estimator__min_samples_leaf=5, estimator__min_samples_split=5, n_estimators=15;, score=0.722 total time=   0.0s
# [CV 4/5] END estimator__max_depth=3, estimator__min_samples_leaf=5, estimator__min_samples_split=5, n_estimators=15;, score=0.621 total time=   0.0s
# [CV 5/5] END estimator__max_depth=3, estimator__min_samples_leaf=5, estimator__min_samples_split=5, n_estimators=15;, score=0.679 total time=   0.0s
# [CV 1/5] END estimator__max_depth=3, estimator__min_samples_leaf=5, estimator__min_samples_split=5, n_estimators=30;, score=0.707 total time=   0.0s
# [CV 2/5] END estimator__max_depth=3, estimator__min_samples_leaf=5, estimator__min_samples_split=5, n_estimators=30;, score=0.634 total time=   0.0s
# [CV 3/5] END estimator__max_depth=3, estimator__min_samples_leaf=5, estimator__min_samples_split=5, n_estimators=30;, score=0.714 total time=   0.0s
# [CV 4/5] END estimator__max_depth=3, estimator__min_samples_leaf=5, estimator__min_samples_split=5, n_estimators=30;, score=0.621 total time=   0.0s
# [CV 5/5] END estimator__max_depth=3, estimator__min_samples_leaf=5, estimator__min_samples_split=5, n_estimators=30;, score=0.676 total time=   0.0s
# [CV 1/5] END estimator__max_depth=3, estimator__min_samples_leaf=5, estimator__min_samples_split=5, n_estimators=50;, score=0.718 total time=   0.0s
# [CV 2/5] END estimator__max_depth=3, estimator__min_samples_leaf=5, estimator__min_samples_split=5, n_estimators=50;, score=0.634 total time=   0.0s
# [CV 3/5] END estimator__max_depth=3, estimator__min_samples_leaf=5, estimator__min_samples_split=5, n_estimators=50;, score=0.711 total time=   0.0s
# [CV 4/5] END estimator__max_depth=3, estimator__min_samples_leaf=5, estimator__min_samples_split=5, n_estimators=50;, score=0.634 total time=   0.0s
# [CV 5/5] END estimator__max_depth=3, estimator__min_samples_leaf=5, estimator__min_samples_split=5, n_estimators=50;, score=0.673 total time=   0.0s
# [CV 1/5] END estimator__max_depth=3, estimator__min_samples_leaf=5, estimator__min_samples_split=10, n_estimators=15;, score=0.696 total time=   0.0s
# [CV 2/5] END estimator__max_depth=3, estimator__min_samples_leaf=5, estimator__min_samples_split=10, n_estimators=15;, score=0.622 total time=   0.0s
# [CV 3/5] END estimator__max_depth=3, estimator__min_samples_leaf=5, estimator__min_samples_split=10, n_estimators=15;, score=0.722 total time=   0.0s
# [CV 4/5] END estimator__max_depth=3, estimator__min_samples_leaf=5, estimator__min_samples_split=10, n_estimators=15;, score=0.621 total time=   0.0s
# [CV 5/5] END estimator__max_depth=3, estimator__min_samples_leaf=5, estimator__min_samples_split=10, n_estimators=15;, score=0.679 total time=   0.0s
# [CV 1/5] END estimator__max_depth=3, estimator__min_samples_leaf=5, estimator__min_samples_split=10, n_estimators=30;, score=0.707 total time=   0.0s
# [CV 2/5] END estimator__max_depth=3, estimator__min_samples_leaf=5, estimator__min_samples_split=10, n_estimators=30;, score=0.634 total time=   0.0s
# [CV 3/5] END estimator__max_depth=3, estimator__min_samples_leaf=5, estimator__min_samples_split=10, n_estimators=30;, score=0.714 total time=   0.0s
# [CV 4/5] END estimator__max_depth=3, estimator__min_samples_leaf=5, estimator__min_samples_split=10, n_estimators=30;, score=0.621 total time=   0.0s
# [CV 5/5] END estimator__max_depth=3, estimator__min_samples_leaf=5, estimator__min_samples_split=10, n_estimators=30;, score=0.676 total time=   0.0s
# [CV 1/5] END estimator__max_depth=3, estimator__min_samples_leaf=5, estimator__min_samples_split=10, n_estimators=50;, score=0.718 total time=   0.0s
# [CV 2/5] END estimator__max_depth=3, estimator__min_samples_leaf=5, estimator__min_samples_split=10, n_estimators=50;, score=0.634 total time=   0.0s
# [CV 3/5] END estimator__max_depth=3, estimator__min_samples_leaf=5, estimator__min_samples_split=10, n_estimators=50;, score=0.711 total time=   0.0s
# [CV 4/5] END estimator__max_depth=3, estimator__min_samples_leaf=5, estimator__min_samples_split=10, n_estimators=50;, score=0.634 total time=   0.0s
# [CV 5/5] END estimator__max_depth=3, estimator__min_samples_leaf=5, estimator__min_samples_split=10, n_estimators=50;, score=0.673 total time=   0.0s
# [CV 1/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=15;, score=0.697 total time=   0.0s
# [CV 2/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=15;, score=0.621 total time=   0.0s
# [CV 3/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=15;, score=0.723 total time=   0.0s
# [CV 4/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=15;, score=0.622 total time=   0.0s
# [CV 5/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=15;, score=0.679 total time=   0.0s
# [CV 1/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=30;, score=0.709 total time=   0.0s
# [CV 2/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=30;, score=0.634 total time=   0.0s
# [CV 3/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=30;, score=0.714 total time=   0.0s
# [CV 4/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=30;, score=0.620 total time=   0.0s
# [CV 5/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=30;, score=0.676 total time=   0.0s
# [CV 1/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=50;, score=0.719 total time=   0.0s
# [CV 2/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=50;, score=0.634 total time=   0.0s
# [CV 3/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=50;, score=0.712 total time=   0.0s
# [CV 4/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=50;, score=0.633 total time=   0.0s
# [CV 5/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=50;, score=0.673 total time=   0.0s
# [CV 1/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=5, n_estimators=15;, score=0.697 total time=   0.0s
# [CV 2/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=5, n_estimators=15;, score=0.621 total time=   0.0s
# [CV 3/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=5, n_estimators=15;, score=0.723 total time=   0.0s
# [CV 4/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=5, n_estimators=15;, score=0.622 total time=   0.0s
# [CV 5/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=5, n_estimators=15;, score=0.679 total time=   0.0s
# [CV 1/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=5, n_estimators=30;, score=0.709 total time=   0.0s
# [CV 2/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=5, n_estimators=30;, score=0.634 total time=   0.0s
# [CV 3/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=5, n_estimators=30;, score=0.714 total time=   0.0s
# [CV 4/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=5, n_estimators=30;, score=0.620 total time=   0.0s
# [CV 5/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=5, n_estimators=30;, score=0.676 total time=   0.0s
# [CV 1/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=5, n_estimators=50;, score=0.719 total time=   0.0s
# [CV 2/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=5, n_estimators=50;, score=0.634 total time=   0.0s
# [CV 3/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=5, n_estimators=50;, score=0.712 total time=   0.0s
# [CV 4/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=5, n_estimators=50;, score=0.633 total time=   0.0s
# [CV 5/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=5, n_estimators=50;, score=0.673 total time=   0.0s
# [CV 1/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=15;, score=0.697 total time=   0.0s
# [CV 2/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=15;, score=0.621 total time=   0.0s
# [CV 3/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=15;, score=0.723 total time=   0.0s
# [CV 4/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=15;, score=0.622 total time=   0.0s
# [CV 5/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=15;, score=0.679 total time=   0.0s
# [CV 1/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=30;, score=0.709 total time=   0.0s
# [CV 2/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=30;, score=0.634 total time=   0.0s
# [CV 3/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=30;, score=0.714 total time=   0.0s
# [CV 4/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=30;, score=0.620 total time=   0.0s
# [CV 5/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=30;, score=0.676 total time=   0.0s
# [CV 1/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=50;, score=0.719 total time=   0.0s
# [CV 2/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=50;, score=0.634 total time=   0.0s
# [CV 3/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=50;, score=0.712 total time=   0.0s
# [CV 4/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=50;, score=0.633 total time=   0.0s
# [CV 5/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=50;, score=0.673 total time=   0.0s
# [CV 1/5] END estimator__max_depth=5, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=15;, score=0.832 total time=   0.0s
# [CV 2/5] END estimator__max_depth=5, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=15;, score=0.777 total time=   0.0s
# [CV 3/5] END estimator__max_depth=5, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=15;, score=0.861 total time=   0.0s
# [CV 4/5] END estimator__max_depth=5, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=15;, score=0.821 total time=   0.0s
# [CV 5/5] END estimator__max_depth=5, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=15;, score=0.830 total time=   0.0s
# [CV 1/5] END estimator__max_depth=5, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=30;, score=0.837 total time=   0.0s
# [CV 2/5] END estimator__max_depth=5, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=30;, score=0.786 total time=   0.0s
# [CV 3/5] END estimator__max_depth=5, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=30;, score=0.859 total time=   0.0s
# [CV 4/5] END estimator__max_depth=5, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=30;, score=0.833 total time=   0.0s
# [CV 5/5] END estimator__max_depth=5, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=30;, score=0.831 total time=   0.0s
# [CV 1/5] END estimator__max_depth=5, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=50;, score=0.840 total time=   0.0s
# [CV 2/5] END estimator__max_depth=5, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=50;, score=0.787 total time=   0.0s
# [CV 3/5] END estimator__max_depth=5, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=50;, score=0.858 total time=   0.0s
# [CV 4/5] END estimator__max_depth=5, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=50;, score=0.830 total time=   0.0s
# [CV 5/5] END estimator__max_depth=5, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=50;, score=0.828 total time=   0.0s
# [CV 1/5] END estimator__max_depth=5, estimator__min_samples_leaf=1, estimator__min_samples_split=5, n_estimators=15;, score=0.832 total time=   0.0s
# [CV 2/5] END estimator__max_depth=5, estimator__min_samples_leaf=1, estimator__min_samples_split=5, n_estimators=15;, score=0.778 total time=   0.0s
# [CV 3/5] END estimator__max_depth=5, estimator__min_samples_leaf=1, estimator__min_samples_split=5, n_estimators=15;, score=0.861 total time=   0.0s
# [CV 4/5] END estimator__max_depth=5, estimator__min_samples_leaf=1, estimator__min_samples_split=5, n_estimators=15;, score=0.821 total time=   0.0s
# [CV 5/5] END estimator__max_depth=5, estimator__min_samples_leaf=1, estimator__min_samples_split=5, n_estimators=15;, score=0.830 total time=   0.0s
# [CV 1/5] END estimator__max_depth=5, estimator__min_samples_leaf=1, estimator__min_samples_split=5, n_estimators=30;, score=0.837 total time=   0.0s
# [CV 2/5] END estimator__max_depth=5, estimator__min_samples_leaf=1, estimator__min_samples_split=5, n_estimators=30;, score=0.785 total time=   0.0s
# [CV 3/5] END estimator__max_depth=5, estimator__min_samples_leaf=1, estimator__min_samples_split=5, n_estimators=30;, score=0.859 total time=   0.0s
# [CV 4/5] END estimator__max_depth=5, estimator__min_samples_leaf=1, estimator__min_samples_split=5, n_estimators=30;, score=0.833 total time=   0.0s
# [CV 5/5] END estimator__max_depth=5, estimator__min_samples_leaf=1, estimator__min_samples_split=5, n_estimators=30;, score=0.831 total time=   0.0s
# [CV 1/5] END estimator__max_depth=5, estimator__min_samples_leaf=1, estimator__min_samples_split=5, n_estimators=50;, score=0.840 total time=   0.0s
# [CV 2/5] END estimator__max_depth=5, estimator__min_samples_leaf=1, estimator__min_samples_split=5, n_estimators=50;, score=0.787 total time=   0.0s
# [CV 3/5] END estimator__max_depth=5, estimator__min_samples_leaf=1, estimator__min_samples_split=5, n_estimators=50;, score=0.858 total time=   0.0s
# [CV 4/5] END estimator__max_depth=5, estimator__min_samples_leaf=1, estimator__min_samples_split=5, n_estimators=50;, score=0.829 total time=   0.0s
# [CV 5/5] END estimator__max_depth=5, estimator__min_samples_leaf=1, estimator__min_samples_split=5, n_estimators=50;, score=0.828 total time=   0.0s
# [CV 1/5] END estimator__max_depth=5, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=15;, score=0.828 total time=   0.0s
# [CV 2/5] END estimator__max_depth=5, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=15;, score=0.776 total time=   0.0s
# [CV 3/5] END estimator__max_depth=5, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=15;, score=0.860 total time=   0.0s
# [CV 4/5] END estimator__max_depth=5, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=15;, score=0.820 total time=   0.0s
# [CV 5/5] END estimator__max_depth=5, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=15;, score=0.827 total time=   0.0s
# [CV 1/5] END estimator__max_depth=5, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=30;, score=0.834 total time=   0.0s
# [CV 2/5] END estimator__max_depth=5, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=30;, score=0.784 total time=   0.0s
# [CV 3/5] END estimator__max_depth=5, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=30;, score=0.859 total time=   0.0s
# [CV 4/5] END estimator__max_depth=5, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=30;, score=0.831 total time=   0.0s
# [CV 5/5] END estimator__max_depth=5, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=30;, score=0.829 total time=   0.0s
# [CV 1/5] END estimator__max_depth=5, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=50;, score=0.838 total time=   0.0s
# [CV 2/5] END estimator__max_depth=5, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=50;, score=0.786 total time=   0.0s
# [CV 3/5] END estimator__max_depth=5, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=50;, score=0.857 total time=   0.0s
# [CV 4/5] END estimator__max_depth=5, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=50;, score=0.829 total time=   0.0s
# [CV 5/5] END estimator__max_depth=5, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=50;, score=0.826 total time=   0.0s
# [CV 1/5] END estimator__max_depth=5, estimator__min_samples_leaf=5, estimator__min_samples_split=2, n_estimators=15;, score=0.823 total time=   0.0s
# [CV 2/5] END estimator__max_depth=5, estimator__min_samples_leaf=5, estimator__min_samples_split=2, n_estimators=15;, score=0.769 total time=   0.0s
# [CV 3/5] END estimator__max_depth=5, estimator__min_samples_leaf=5, estimator__min_samples_split=2, n_estimators=15;, score=0.859 total time=   0.0s
# [CV 4/5] END estimator__max_depth=5, estimator__min_samples_leaf=5, estimator__min_samples_split=2, n_estimators=15;, score=0.817 total time=   0.0s
# [CV 5/5] END estimator__max_depth=5, estimator__min_samples_leaf=5, estimator__min_samples_split=2, n_estimators=15;, score=0.827 total time=   0.0s
# [CV 1/5] END estimator__max_depth=5, estimator__min_samples_leaf=5, estimator__min_samples_split=2, n_estimators=30;, score=0.830 total time=   0.0s
# [CV 2/5] END estimator__max_depth=5, estimator__min_samples_leaf=5, estimator__min_samples_split=2, n_estimators=30;, score=0.780 total time=   0.0s
# [CV 3/5] END estimator__max_depth=5, estimator__min_samples_leaf=5, estimator__min_samples_split=2, n_estimators=30;, score=0.859 total time=   0.0s
# [CV 4/5] END estimator__max_depth=5, estimator__min_samples_leaf=5, estimator__min_samples_split=2, n_estimators=30;, score=0.825 total time=   0.0s
# [CV 5/5] END estimator__max_depth=5, estimator__min_samples_leaf=5, estimator__min_samples_split=2, n_estimators=30;, score=0.828 total time=   0.0s
# [CV 1/5] END estimator__max_depth=5, estimator__min_samples_leaf=5, estimator__min_samples_split=2, n_estimators=50;, score=0.835 total time=   0.0s
# [CV 2/5] END estimator__max_depth=5, estimator__min_samples_leaf=5, estimator__min_samples_split=2, n_estimators=50;, score=0.783 total time=   0.0s
# [CV 3/5] END estimator__max_depth=5, estimator__min_samples_leaf=5, estimator__min_samples_split=2, n_estimators=50;, score=0.857 total time=   0.0s
# [CV 4/5] END estimator__max_depth=5, estimator__min_samples_leaf=5, estimator__min_samples_split=2, n_estimators=50;, score=0.823 total time=   0.0s
# [CV 5/5] END estimator__max_depth=5, estimator__min_samples_leaf=5, estimator__min_samples_split=2, n_estimators=50;, score=0.826 total time=   0.0s
# [CV 1/5] END estimator__max_depth=5, estimator__min_samples_leaf=5, estimator__min_samples_split=5, n_estimators=15;, score=0.823 total time=   0.0s
# [CV 2/5] END estimator__max_depth=5, estimator__min_samples_leaf=5, estimator__min_samples_split=5, n_estimators=15;, score=0.769 total time=   0.0s
# [CV 3/5] END estimator__max_depth=5, estimator__min_samples_leaf=5, estimator__min_samples_split=5, n_estimators=15;, score=0.859 total time=   0.0s
# [CV 4/5] END estimator__max_depth=5, estimator__min_samples_leaf=5, estimator__min_samples_split=5, n_estimators=15;, score=0.817 total time=   0.0s
# [CV 5/5] END estimator__max_depth=5, estimator__min_samples_leaf=5, estimator__min_samples_split=5, n_estimators=15;, score=0.827 total time=   0.0s
# [CV 1/5] END estimator__max_depth=5, estimator__min_samples_leaf=5, estimator__min_samples_split=5, n_estimators=30;, score=0.830 total time=   0.0s
# [CV 2/5] END estimator__max_depth=5, estimator__min_samples_leaf=5, estimator__min_samples_split=5, n_estimators=30;, score=0.780 total time=   0.0s
# [CV 3/5] END estimator__max_depth=5, estimator__min_samples_leaf=5, estimator__min_samples_split=5, n_estimators=30;, score=0.859 total time=   0.0s
# [CV 4/5] END estimator__max_depth=5, estimator__min_samples_leaf=5, estimator__min_samples_split=5, n_estimators=30;, score=0.825 total time=   0.0s
# [CV 5/5] END estimator__max_depth=5, estimator__min_samples_leaf=5, estimator__min_samples_split=5, n_estimators=30;, score=0.828 total time=   0.0s
# [CV 1/5] END estimator__max_depth=5, estimator__min_samples_leaf=5, estimator__min_samples_split=5, n_estimators=50;, score=0.835 total time=   0.0s
# [CV 2/5] END estimator__max_depth=5, estimator__min_samples_leaf=5, estimator__min_samples_split=5, n_estimators=50;, score=0.783 total time=   0.0s
# [CV 3/5] END estimator__max_depth=5, estimator__min_samples_leaf=5, estimator__min_samples_split=5, n_estimators=50;, score=0.857 total time=   0.0s
# [CV 4/5] END estimator__max_depth=5, estimator__min_samples_leaf=5, estimator__min_samples_split=5, n_estimators=50;, score=0.823 total time=   0.0s
# [CV 5/5] END estimator__max_depth=5, estimator__min_samples_leaf=5, estimator__min_samples_split=5, n_estimators=50;, score=0.826 total time=   0.0s
# [CV 1/5] END estimator__max_depth=5, estimator__min_samples_leaf=5, estimator__min_samples_split=10, n_estimators=15;, score=0.823 total time=   0.0s
# [CV 2/5] END estimator__max_depth=5, estimator__min_samples_leaf=5, estimator__min_samples_split=10, n_estimators=15;, score=0.769 total time=   0.0s
# [CV 3/5] END estimator__max_depth=5, estimator__min_samples_leaf=5, estimator__min_samples_split=10, n_estimators=15;, score=0.859 total time=   0.0s
# [CV 4/5] END estimator__max_depth=5, estimator__min_samples_leaf=5, estimator__min_samples_split=10, n_estimators=15;, score=0.817 total time=   0.0s
# [CV 5/5] END estimator__max_depth=5, estimator__min_samples_leaf=5, estimator__min_samples_split=10, n_estimators=15;, score=0.827 total time=   0.0s
# [CV 1/5] END estimator__max_depth=5, estimator__min_samples_leaf=5, estimator__min_samples_split=10, n_estimators=30;, score=0.830 total time=   0.0s
# [CV 2/5] END estimator__max_depth=5, estimator__min_samples_leaf=5, estimator__min_samples_split=10, n_estimators=30;, score=0.780 total time=   0.0s
# [CV 3/5] END estimator__max_depth=5, estimator__min_samples_leaf=5, estimator__min_samples_split=10, n_estimators=30;, score=0.859 total time=   0.0s
# [CV 4/5] END estimator__max_depth=5, estimator__min_samples_leaf=5, estimator__min_samples_split=10, n_estimators=30;, score=0.825 total time=   0.0s
# [CV 5/5] END estimator__max_depth=5, estimator__min_samples_leaf=5, estimator__min_samples_split=10, n_estimators=30;, score=0.828 total time=   0.0s
# [CV 1/5] END estimator__max_depth=5, estimator__min_samples_leaf=5, estimator__min_samples_split=10, n_estimators=50;, score=0.835 total time=   0.0s
# [CV 2/5] END estimator__max_depth=5, estimator__min_samples_leaf=5, estimator__min_samples_split=10, n_estimators=50;, score=0.783 total time=   0.0s
# [CV 3/5] END estimator__max_depth=5, estimator__min_samples_leaf=5, estimator__min_samples_split=10, n_estimators=50;, score=0.857 total time=   0.0s
# [CV 4/5] END estimator__max_depth=5, estimator__min_samples_leaf=5, estimator__min_samples_split=10, n_estimators=50;, score=0.823 total time=   0.0s
# [CV 5/5] END estimator__max_depth=5, estimator__min_samples_leaf=5, estimator__min_samples_split=10, n_estimators=50;, score=0.826 total time=   0.0s
# [CV 1/5] END estimator__max_depth=5, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=15;, score=0.814 total time=   0.0s
# [CV 2/5] END estimator__max_depth=5, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=15;, score=0.750 total time=   0.0s
# [CV 3/5] END estimator__max_depth=5, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=15;, score=0.855 total time=   0.0s
# [CV 4/5] END estimator__max_depth=5, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=15;, score=0.798 total time=   0.0s
# [CV 5/5] END estimator__max_depth=5, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=15;, score=0.820 total time=   0.0s
# [CV 1/5] END estimator__max_depth=5, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=30;, score=0.827 total time=   0.0s
# [CV 2/5] END estimator__max_depth=5, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=30;, score=0.761 total time=   0.0s
# [CV 3/5] END estimator__max_depth=5, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=30;, score=0.855 total time=   0.0s
# [CV 4/5] END estimator__max_depth=5, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=30;, score=0.809 total time=   0.0s
# [CV 5/5] END estimator__max_depth=5, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=30;, score=0.818 total time=   0.0s
# [CV 1/5] END estimator__max_depth=5, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=50;, score=0.829 total time=   0.0s
# [CV 2/5] END estimator__max_depth=5, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=50;, score=0.764 total time=   0.0s
# [CV 3/5] END estimator__max_depth=5, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=50;, score=0.853 total time=   0.0s
# [CV 4/5] END estimator__max_depth=5, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=50;, score=0.808 total time=   0.0s
# [CV 5/5] END estimator__max_depth=5, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=50;, score=0.816 total time=   0.0s
# [CV 1/5] END estimator__max_depth=5, estimator__min_samples_leaf=10, estimator__min_samples_split=5, n_estimators=15;, score=0.814 total time=   0.0s
# [CV 2/5] END estimator__max_depth=5, estimator__min_samples_leaf=10, estimator__min_samples_split=5, n_estimators=15;, score=0.750 total time=   0.0s
# [CV 3/5] END estimator__max_depth=5, estimator__min_samples_leaf=10, estimator__min_samples_split=5, n_estimators=15;, score=0.855 total time=   0.0s
# [CV 4/5] END estimator__max_depth=5, estimator__min_samples_leaf=10, estimator__min_samples_split=5, n_estimators=15;, score=0.798 total time=   0.0s
# [CV 5/5] END estimator__max_depth=5, estimator__min_samples_leaf=10, estimator__min_samples_split=5, n_estimators=15;, score=0.820 total time=   0.0s
# [CV 1/5] END estimator__max_depth=5, estimator__min_samples_leaf=10, estimator__min_samples_split=5, n_estimators=30;, score=0.827 total time=   0.0s
# [CV 2/5] END estimator__max_depth=5, estimator__min_samples_leaf=10, estimator__min_samples_split=5, n_estimators=30;, score=0.761 total time=   0.0s
# [CV 3/5] END estimator__max_depth=5, estimator__min_samples_leaf=10, estimator__min_samples_split=5, n_estimators=30;, score=0.855 total time=   0.0s
# [CV 4/5] END estimator__max_depth=5, estimator__min_samples_leaf=10, estimator__min_samples_split=5, n_estimators=30;, score=0.809 total time=   0.0s
# [CV 5/5] END estimator__max_depth=5, estimator__min_samples_leaf=10, estimator__min_samples_split=5, n_estimators=30;, score=0.818 total time=   0.0s
# [CV 1/5] END estimator__max_depth=5, estimator__min_samples_leaf=10, estimator__min_samples_split=5, n_estimators=50;, score=0.829 total time=   0.0s
# [CV 2/5] END estimator__max_depth=5, estimator__min_samples_leaf=10, estimator__min_samples_split=5, n_estimators=50;, score=0.764 total time=   0.0s
# [CV 3/5] END estimator__max_depth=5, estimator__min_samples_leaf=10, estimator__min_samples_split=5, n_estimators=50;, score=0.853 total time=   0.0s
# [CV 4/5] END estimator__max_depth=5, estimator__min_samples_leaf=10, estimator__min_samples_split=5, n_estimators=50;, score=0.808 total time=   0.0s
# [CV 5/5] END estimator__max_depth=5, estimator__min_samples_leaf=10, estimator__min_samples_split=5, n_estimators=50;, score=0.816 total time=   0.0s
# [CV 1/5] END estimator__max_depth=5, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=15;, score=0.814 total time=   0.0s
# [CV 2/5] END estimator__max_depth=5, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=15;, score=0.750 total time=   0.0s
# [CV 3/5] END estimator__max_depth=5, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=15;, score=0.855 total time=   0.0s
# [CV 4/5] END estimator__max_depth=5, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=15;, score=0.798 total time=   0.0s
# [CV 5/5] END estimator__max_depth=5, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=15;, score=0.820 total time=   0.0s
# [CV 1/5] END estimator__max_depth=5, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=30;, score=0.827 total time=   0.0s
# [CV 2/5] END estimator__max_depth=5, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=30;, score=0.761 total time=   0.0s
# [CV 3/5] END estimator__max_depth=5, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=30;, score=0.855 total time=   0.0s
# [CV 4/5] END estimator__max_depth=5, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=30;, score=0.809 total time=   0.0s
# [CV 5/5] END estimator__max_depth=5, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=30;, score=0.818 total time=   0.0s
# [CV 1/5] END estimator__max_depth=5, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=50;, score=0.829 total time=   0.0s
# [CV 2/5] END estimator__max_depth=5, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=50;, score=0.764 total time=   0.0s
# [CV 3/5] END estimator__max_depth=5, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=50;, score=0.853 total time=   0.0s
# [CV 4/5] END estimator__max_depth=5, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=50;, score=0.808 total time=   0.0s
# [CV 5/5] END estimator__max_depth=5, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=50;, score=0.816 total time=   0.0s
# Best Parameters: {'estimator__max_depth': None, 'estimator__min_samples_leaf': 1, 'estimator__min_samples_split': 2, 'n_estimators': 50}
# Best Score: 0.9087693424682135
