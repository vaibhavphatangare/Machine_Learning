# %%
# Import necessary libraries
from sklearn.linear_model import Ridge, LinearRegression, LogisticRegression
from sklearn.metrics import accuracy_score,log_loss,r2_score
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import GridSearchCV,train_test_split ,StratifiedKFold,KFold
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.tree import DecisionTreeClassifier,DecisionTreeRegressor
from sklearn.ensemble import VotingClassifier, BaggingClassifier,BaggingRegressor,RandomForestClassifier,RandomForestRegressor
from sklearn.neighbors import *
from sklearn.svm import SVC
from sklearn.pipeline import *
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import warnings
import os

warnings.simplefilter('ignore')

os.chdir('D:\kaggla_comp\hardness')

train = pd.read_csv('train.csv')
train
# Out:
#           id  allelectrons_Total  density_Total  allelectrons_Average  \
# 0          0               100.0       0.841611             10.000000
# 1          1               100.0       7.558488             10.000000
# 2          2                76.0       8.885992             15.600000
# 3          3               100.0       8.795296             10.000000
# 4          4               116.0       9.577996             11.600000
# ...      ...                 ...            ...                   ...
# 10402  10402               128.0       7.558488             12.000000
# 10403  10403                30.0       1.743160             10.000000
# 10404  10404               196.0      30.920000             24.500000
# 10405  10405                38.0       1.553160             12.666667
# 10406  10406               288.0      24.655328             11.142857
#
#        val_e_Average  atomicweight_Average  ionenergy_Average  \
# 0           4.800000             20.612526          11.088100
# 1           4.800000             20.298893          12.040830
# 2           5.600000             33.739258          12.086300
# 3           4.800000             20.213349          10.948500
# 4           4.800000             24.988133          11.824480
# ...              ...                   ...                ...
# 10402       4.000000             26.385218          11.330440
# 10403       5.333333             20.766935          14.163933
# 10404       5.500000             53.490297          10.074300
# 10405       4.666667             26.621687          11.290033
# 10406       4.571429             22.536126          10.960357
#
#        el_neg_chi_Average  R_vdw_element_Average  R_cov_element_Average  \
# 0                2.766000               1.732000               0.860000
# 1                2.755000               1.631000               0.910000
# 2                2.828000               1.788000               0.864000
# 3                2.648000               1.626000               0.936000
# 4                2.766000               1.682000               0.896000
# ...                   ...                    ...                    ...
# 10402            2.644000               1.631000               0.892000
# 10403            3.090000               1.556667               0.866667
# 10404            2.295000               1.545000               1.120000
# 10405            2.743333               1.756667               0.980000
# 10406            2.792143               1.772857               0.940000
#
#        zaratio_Average  density_Average  Hardness
# 0             0.496070          0.91457       6.0
# 1             0.492719          0.71760       6.5
# 2             0.481478          1.50633       2.5
# 3             0.489272          0.78937       6.0
# 4             0.492736          1.86481       6.0
# ...                ...              ...       ...
# 10402         0.496070          1.79607       4.0
# 10403         0.480390          0.81480       5.0
# 10404         0.469715          2.11540       1.8
# 10405         0.486507          0.77755       6.0
# 10406         0.493919          0.97737       6.5
#
# [10407 rows x 13 columns]

# %%
x= train.drop('Hardness',axis=1)
y=train['Hardness']

# %%
# Define the parameter grid for hyperparameter tuning
params = {
    'max_features': [3, 4, 5, 6, 7],
    'max_depth': [None, 3, 5],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 5, 10]
}

# Create a K-Fold cross-validation object with 5 splits, shuffling the data, and a random state of 24
kfold = KFold(n_splits=5, shuffle=True, random_state=24)

# Create a Random Forest Regressor with a random state of 24
rf = RandomForestRegressor(random_state=24)

# Create a GridSearchCV object to perform cross-validation and hyperparameter tuning
# Use the Random Forest Regressor as the estimator, the parameter grid defined above, the K-Fold cross-validation,
# set the verbosity to 3
gcv = GridSearchCV(rf, param_grid=params, verbose=3, cv=kfold)

# Fit the GridSearchCV object to the entire dataset (x and y)
gcv.fit(x, y)

# Print the best parameters found by the GridSearchCV
print("Best Parameters:", gcv.best_params_)

# Print the best score found by the GridSearchCV
print("Best Score:", gcv.best_score_)
# Out:
# Fitting 5 folds for each of 135 candidates, totalling 675 fits
# [CV 1/5] END max_depth=None, max_features=3, min_samples_leaf=1, min_samples_split=2;, score=0.479 total time=   2.6s
# [CV 2/5] END max_depth=None, max_features=3, min_samples_leaf=1, min_samples_split=2;, score=0.453 total time=   2.5s
# [CV 3/5] END max_depth=None, max_features=3, min_samples_leaf=1, min_samples_split=2;, score=0.456 total time=   2.5s
# [CV 4/5] END max_depth=None, max_features=3, min_samples_leaf=1, min_samples_split=2;, score=0.464 total time=   2.5s
# [CV 5/5] END max_depth=None, max_features=3, min_samples_leaf=1, min_samples_split=2;, score=0.480 total time=   2.5s
# [CV 1/5] END max_depth=None, max_features=3, min_samples_leaf=1, min_samples_split=5;, score=0.481 total time=   2.2s
# [CV 2/5] END max_depth=None, max_features=3, min_samples_leaf=1, min_samples_split=5;, score=0.459 total time=   2.3s
# [CV 3/5] END max_depth=None, max_features=3, min_samples_leaf=1, min_samples_split=5;, score=0.465 total time=   2.2s
# [CV 4/5] END max_depth=None, max_features=3, min_samples_leaf=1, min_samples_split=5;, score=0.470 total time=   2.2s
# [CV 5/5] END max_depth=None, max_features=3, min_samples_leaf=1, min_samples_split=5;, score=0.481 total time=   2.2s
# [CV 1/5] END max_depth=None, max_features=3, min_samples_leaf=1, min_samples_split=10;, score=0.480 total time=   2.0s
# [CV 2/5] END max_depth=None, max_features=3, min_samples_leaf=1, min_samples_split=10;, score=0.458 total time=   1.9s
# [CV 3/5] END max_depth=None, max_features=3, min_samples_leaf=1, min_samples_split=10;, score=0.464 total time=   1.9s
# [CV 4/5] END max_depth=None, max_features=3, min_samples_leaf=1, min_samples_split=10;, score=0.467 total time=   2.0s
# [CV 5/5] END max_depth=None, max_features=3, min_samples_leaf=1, min_samples_split=10;, score=0.486 total time=   1.9s
# [CV 1/5] END max_depth=None, max_features=3, min_samples_leaf=5, min_samples_split=2;, score=0.487 total time=   1.5s
# [CV 2/5] END max_depth=None, max_features=3, min_samples_leaf=5, min_samples_split=2;, score=0.462 total time=   1.5s
# [CV 3/5] END max_depth=None, max_features=3, min_samples_leaf=5, min_samples_split=2;, score=0.467 total time=   1.6s
# [CV 4/5] END max_depth=None, max_features=3, min_samples_leaf=5, min_samples_split=2;, score=0.471 total time=   1.5s
# [CV 5/5] END max_depth=None, max_features=3, min_samples_leaf=5, min_samples_split=2;, score=0.484 total time=   1.6s
# [CV 1/5] END max_depth=None, max_features=3, min_samples_leaf=5, min_samples_split=5;, score=0.487 total time=   1.5s
# [CV 2/5] END max_depth=None, max_features=3, min_samples_leaf=5, min_samples_split=5;, score=0.462 total time=   1.5s
# [CV 3/5] END max_depth=None, max_features=3, min_samples_leaf=5, min_samples_split=5;, score=0.467 total time=   1.6s
# [CV 4/5] END max_depth=None, max_features=3, min_samples_leaf=5, min_samples_split=5;, score=0.471 total time=   1.6s
# [CV 5/5] END max_depth=None, max_features=3, min_samples_leaf=5, min_samples_split=5;, score=0.484 total time=   1.5s
# [CV 1/5] END max_depth=None, max_features=3, min_samples_leaf=5, min_samples_split=10;, score=0.487 total time=   1.5s
# [CV 2/5] END max_depth=None, max_features=3, min_samples_leaf=5, min_samples_split=10;, score=0.462 total time=   1.5s
# [CV 3/5] END max_depth=None, max_features=3, min_samples_leaf=5, min_samples_split=10;, score=0.467 total time=   1.6s
# [CV 4/5] END max_depth=None, max_features=3, min_samples_leaf=5, min_samples_split=10;, score=0.471 total time=   1.5s
# [CV 5/5] END max_depth=None, max_features=3, min_samples_leaf=5, min_samples_split=10;, score=0.484 total time=   1.5s
# [CV 1/5] END max_depth=None, max_features=3, min_samples_leaf=10, min_samples_split=2;, score=0.478 total time=   1.3s
# [CV 2/5] END max_depth=None, max_features=3, min_samples_leaf=10, min_samples_split=2;, score=0.456 total time=   1.3s
# [CV 3/5] END max_depth=None, max_features=3, min_samples_leaf=10, min_samples_split=2;, score=0.463 total time=   1.3s
# [CV 4/5] END max_depth=None, max_features=3, min_samples_leaf=10, min_samples_split=2;, score=0.463 total time=   1.3s
# [CV 5/5] END max_depth=None, max_features=3, min_samples_leaf=10, min_samples_split=2;, score=0.477 total time=   1.3s
# [CV 1/5] END max_depth=None, max_features=3, min_samples_leaf=10, min_samples_split=5;, score=0.478 total time=   1.3s
# [CV 2/5] END max_depth=None, max_features=3, min_samples_leaf=10, min_samples_split=5;, score=0.456 total time=   1.3s
# [CV 3/5] END max_depth=None, max_features=3, min_samples_leaf=10, min_samples_split=5;, score=0.463 total time=   1.3s
# [CV 4/5] END max_depth=None, max_features=3, min_samples_leaf=10, min_samples_split=5;, score=0.463 total time=   1.3s
# [CV 5/5] END max_depth=None, max_features=3, min_samples_leaf=10, min_samples_split=5;, score=0.477 total time=   1.3s
# [CV 1/5] END max_depth=None, max_features=3, min_samples_leaf=10, min_samples_split=10;, score=0.478 total time=   1.3s
# [CV 2/5] END max_depth=None, max_features=3, min_samples_leaf=10, min_samples_split=10;, score=0.456 total time=   1.3s
# [CV 3/5] END max_depth=None, max_features=3, min_samples_leaf=10, min_samples_split=10;, score=0.463 total time=   1.3s
# [CV 4/5] END max_depth=None, max_features=3, min_samples_leaf=10, min_samples_split=10;, score=0.463 total time=   1.3s
# [CV 5/5] END max_depth=None, max_features=3, min_samples_leaf=10, min_samples_split=10;, score=0.477 total time=   1.3s
# [CV 1/5] END max_depth=None, max_features=4, min_samples_leaf=1, min_samples_split=2;, score=0.478 total time=   3.1s
# [CV 2/5] END max_depth=None, max_features=4, min_samples_leaf=1, min_samples_split=2;, score=0.461 total time=   3.1s
# [CV 3/5] END max_depth=None, max_features=4, min_samples_leaf=1, min_samples_split=2;, score=0.455 total time=   3.1s
# [CV 4/5] END max_depth=None, max_features=4, min_samples_leaf=1, min_samples_split=2;, score=0.470 total time=   3.1s
# [CV 5/5] END max_depth=None, max_features=4, min_samples_leaf=1, min_samples_split=2;, score=0.478 total time=   3.2s
# [CV 1/5] END max_depth=None, max_features=4, min_samples_leaf=1, min_samples_split=5;, score=0.474 total time=   2.8s
# [CV 2/5] END max_depth=None, max_features=4, min_samples_leaf=1, min_samples_split=5;, score=0.457 total time=   2.8s
# [CV 3/5] END max_depth=None, max_features=4, min_samples_leaf=1, min_samples_split=5;, score=0.462 total time=   2.8s
# [CV 4/5] END max_depth=None, max_features=4, min_samples_leaf=1, min_samples_split=5;, score=0.471 total time=   2.8s
# [CV 5/5] END max_depth=None, max_features=4, min_samples_leaf=1, min_samples_split=5;, score=0.478 total time=   2.8s
# [CV 1/5] END max_depth=None, max_features=4, min_samples_leaf=1, min_samples_split=10;, score=0.479 total time=   2.6s
# [CV 2/5] END max_depth=None, max_features=4, min_samples_leaf=1, min_samples_split=10;, score=0.459 total time=   2.5s
# [CV 3/5] END max_depth=None, max_features=4, min_samples_leaf=1, min_samples_split=10;, score=0.457 total time=   2.6s
# [CV 4/5] END max_depth=None, max_features=4, min_samples_leaf=1, min_samples_split=10;, score=0.470 total time=   2.6s
# [CV 5/5] END max_depth=None, max_features=4, min_samples_leaf=1, min_samples_split=10;, score=0.485 total time=   2.5s
# [CV 1/5] END max_depth=None, max_features=4, min_samples_leaf=5, min_samples_split=2;, score=0.485 total time=   2.0s
# [CV 2/5] END max_depth=None, max_features=4, min_samples_leaf=5, min_samples_split=2;, score=0.459 total time=   2.0s
# [CV 3/5] END max_depth=None, max_features=4, min_samples_leaf=5, min_samples_split=2;, score=0.466 total time=   2.0s
# [CV 4/5] END max_depth=None, max_features=4, min_samples_leaf=5, min_samples_split=2;, score=0.471 total time=   2.0s
# [CV 5/5] END max_depth=None, max_features=4, min_samples_leaf=5, min_samples_split=2;, score=0.487 total time=   2.0s
# [CV 1/5] END max_depth=None, max_features=4, min_samples_leaf=5, min_samples_split=5;, score=0.485 total time=   2.0s
# [CV 2/5] END max_depth=None, max_features=4, min_samples_leaf=5, min_samples_split=5;, score=0.459 total time=   2.0s
# [CV 3/5] END max_depth=None, max_features=4, min_samples_leaf=5, min_samples_split=5;, score=0.466 total time=   2.0s
# [CV 4/5] END max_depth=None, max_features=4, min_samples_leaf=5, min_samples_split=5;, score=0.471 total time=   2.0s
# [CV 5/5] END max_depth=None, max_features=4, min_samples_leaf=5, min_samples_split=5;, score=0.487 total time=   2.1s
# [CV 1/5] END max_depth=None, max_features=4, min_samples_leaf=5, min_samples_split=10;, score=0.485 total time=   2.0s
# [CV 2/5] END max_depth=None, max_features=4, min_samples_leaf=5, min_samples_split=10;, score=0.459 total time=   2.0s
# [CV 3/5] END max_depth=None, max_features=4, min_samples_leaf=5, min_samples_split=10;, score=0.466 total time=   2.0s
# [CV 4/5] END max_depth=None, max_features=4, min_samples_leaf=5, min_samples_split=10;, score=0.471 total time=   2.0s
# [CV 5/5] END max_depth=None, max_features=4, min_samples_leaf=5, min_samples_split=10;, score=0.487 total time=   2.0s
# [CV 1/5] END max_depth=None, max_features=4, min_samples_leaf=10, min_samples_split=2;, score=0.478 total time=   1.7s
# [CV 2/5] END max_depth=None, max_features=4, min_samples_leaf=10, min_samples_split=2;, score=0.454 total time=   1.6s
# [CV 3/5] END max_depth=None, max_features=4, min_samples_leaf=10, min_samples_split=2;, score=0.461 total time=   1.7s
# [CV 4/5] END max_depth=None, max_features=4, min_samples_leaf=10, min_samples_split=2;, score=0.466 total time=   1.6s
# [CV 5/5] END max_depth=None, max_features=4, min_samples_leaf=10, min_samples_split=2;, score=0.482 total time=   1.6s
# [CV 1/5] END max_depth=None, max_features=4, min_samples_leaf=10, min_samples_split=5;, score=0.478 total time=   1.7s
# [CV 2/5] END max_depth=None, max_features=4, min_samples_leaf=10, min_samples_split=5;, score=0.454 total time=   1.6s
# [CV 3/5] END max_depth=None, max_features=4, min_samples_leaf=10, min_samples_split=5;, score=0.461 total time=   1.7s
# [CV 4/5] END max_depth=None, max_features=4, min_samples_leaf=10, min_samples_split=5;, score=0.466 total time=   1.6s
# [CV 5/5] END max_depth=None, max_features=4, min_samples_leaf=10, min_samples_split=5;, score=0.482 total time=   1.6s
# [CV 1/5] END max_depth=None, max_features=4, min_samples_leaf=10, min_samples_split=10;, score=0.478 total time=   1.7s
# [CV 2/5] END max_depth=None, max_features=4, min_samples_leaf=10, min_samples_split=10;, score=0.454 total time=   1.7s
# [CV 3/5] END max_depth=None, max_features=4, min_samples_leaf=10, min_samples_split=10;, score=0.461 total time=   1.6s
# [CV 4/5] END max_depth=None, max_features=4, min_samples_leaf=10, min_samples_split=10;, score=0.466 total time=   1.6s
# [CV 5/5] END max_depth=None, max_features=4, min_samples_leaf=10, min_samples_split=10;, score=0.482 total time=   1.6s
# [CV 1/5] END max_depth=None, max_features=5, min_samples_leaf=1, min_samples_split=2;, score=0.479 total time=   3.8s
# [CV 2/5] END max_depth=None, max_features=5, min_samples_leaf=1, min_samples_split=2;, score=0.450 total time=   3.7s
# [CV 3/5] END max_depth=None, max_features=5, min_samples_leaf=1, min_samples_split=2;, score=0.458 total time=   3.8s
# [CV 4/5] END max_depth=None, max_features=5, min_samples_leaf=1, min_samples_split=2;, score=0.462 total time=   3.7s
# [CV 5/5] END max_depth=None, max_features=5, min_samples_leaf=1, min_samples_split=2;, score=0.476 total time=   3.7s
# [CV 1/5] END max_depth=None, max_features=5, min_samples_leaf=1, min_samples_split=5;, score=0.483 total time=   3.4s
# [CV 2/5] END max_depth=None, max_features=5, min_samples_leaf=1, min_samples_split=5;, score=0.456 total time=   3.4s
# [CV 3/5] END max_depth=None, max_features=5, min_samples_leaf=1, min_samples_split=5;, score=0.457 total time=   3.4s
# [CV 4/5] END max_depth=None, max_features=5, min_samples_leaf=1, min_samples_split=5;, score=0.465 total time=   3.4s
# [CV 5/5] END max_depth=None, max_features=5, min_samples_leaf=1, min_samples_split=5;, score=0.480 total time=   3.4s
# [CV 1/5] END max_depth=None, max_features=5, min_samples_leaf=1, min_samples_split=10;, score=0.477 total time=   3.1s
# [CV 2/5] END max_depth=None, max_features=5, min_samples_leaf=1, min_samples_split=10;, score=0.456 total time=   3.1s
# [CV 3/5] END max_depth=None, max_features=5, min_samples_leaf=1, min_samples_split=10;, score=0.459 total time=   3.1s
# [CV 4/5] END max_depth=None, max_features=5, min_samples_leaf=1, min_samples_split=10;, score=0.468 total time=   3.1s
# [CV 5/5] END max_depth=None, max_features=5, min_samples_leaf=1, min_samples_split=10;, score=0.483 total time=   3.0s
# [CV 1/5] END max_depth=None, max_features=5, min_samples_leaf=5, min_samples_split=2;, score=0.485 total time=   2.4s
# [CV 2/5] END max_depth=None, max_features=5, min_samples_leaf=5, min_samples_split=2;, score=0.456 total time=   2.4s
# [CV 3/5] END max_depth=None, max_features=5, min_samples_leaf=5, min_samples_split=2;, score=0.467 total time=   2.6s
# [CV 4/5] END max_depth=None, max_features=5, min_samples_leaf=5, min_samples_split=2;, score=0.474 total time=   2.5s
# [CV 5/5] END max_depth=None, max_features=5, min_samples_leaf=5, min_samples_split=2;, score=0.483 total time=   2.4s
# [CV 1/5] END max_depth=None, max_features=5, min_samples_leaf=5, min_samples_split=5;, score=0.485 total time=   2.4s
# [CV 2/5] END max_depth=None, max_features=5, min_samples_leaf=5, min_samples_split=5;, score=0.456 total time=   2.4s
# [CV 3/5] END max_depth=None, max_features=5, min_samples_leaf=5, min_samples_split=5;, score=0.467 total time=   2.5s
# [CV 4/5] END max_depth=None, max_features=5, min_samples_leaf=5, min_samples_split=5;, score=0.474 total time=   2.5s
# [CV 5/5] END max_depth=None, max_features=5, min_samples_leaf=5, min_samples_split=5;, score=0.483 total time=   2.4s
# [CV 1/5] END max_depth=None, max_features=5, min_samples_leaf=5, min_samples_split=10;, score=0.485 total time=   2.4s
# [CV 2/5] END max_depth=None, max_features=5, min_samples_leaf=5, min_samples_split=10;, score=0.456 total time=   2.4s
# [CV 3/5] END max_depth=None, max_features=5, min_samples_leaf=5, min_samples_split=10;, score=0.467 total time=   2.4s
# [CV 4/5] END max_depth=None, max_features=5, min_samples_leaf=5, min_samples_split=10;, score=0.474 total time=   2.4s
# [CV 5/5] END max_depth=None, max_features=5, min_samples_leaf=5, min_samples_split=10;, score=0.483 total time=   2.4s
# [CV 1/5] END max_depth=None, max_features=5, min_samples_leaf=10, min_samples_split=2;, score=0.484 total time=   2.0s
# [CV 2/5] END max_depth=None, max_features=5, min_samples_leaf=10, min_samples_split=2;, score=0.452 total time=   2.0s
# [CV 3/5] END max_depth=None, max_features=5, min_samples_leaf=10, min_samples_split=2;, score=0.462 total time=   2.0s
# [CV 4/5] END max_depth=None, max_features=5, min_samples_leaf=10, min_samples_split=2;, score=0.468 total time=   2.0s
# [CV 5/5] END max_depth=None, max_features=5, min_samples_leaf=10, min_samples_split=2;, score=0.481 total time=   2.0s
# [CV 1/5] END max_depth=None, max_features=5, min_samples_leaf=10, min_samples_split=5;, score=0.484 total time=   2.0s
# [CV 2/5] END max_depth=None, max_features=5, min_samples_leaf=10, min_samples_split=5;, score=0.452 total time=   2.0s
# [CV 3/5] END max_depth=None, max_features=5, min_samples_leaf=10, min_samples_split=5;, score=0.462 total time=   2.0s
# [CV 4/5] END max_depth=None, max_features=5, min_samples_leaf=10, min_samples_split=5;, score=0.468 total time=   2.0s
# [CV 5/5] END max_depth=None, max_features=5, min_samples_leaf=10, min_samples_split=5;, score=0.481 total time=   2.0s
# [CV 1/5] END max_depth=None, max_features=5, min_samples_leaf=10, min_samples_split=10;, score=0.484 total time=   2.1s
# [CV 2/5] END max_depth=None, max_features=5, min_samples_leaf=10, min_samples_split=10;, score=0.452 total time=   2.0s
# [CV 3/5] END max_depth=None, max_features=5, min_samples_leaf=10, min_samples_split=10;, score=0.462 total time=   2.0s
# [CV 4/5] END max_depth=None, max_features=5, min_samples_leaf=10, min_samples_split=10;, score=0.468 total time=   2.0s
# [CV 5/5] END max_depth=None, max_features=5, min_samples_leaf=10, min_samples_split=10;, score=0.481 total time=   2.0s
# [CV 1/5] END max_depth=None, max_features=6, min_samples_leaf=1, min_samples_split=2;, score=0.477 total time=   4.4s
# [CV 2/5] END max_depth=None, max_features=6, min_samples_leaf=1, min_samples_split=2;, score=0.449 total time=   4.3s
# [CV 3/5] END max_depth=None, max_features=6, min_samples_leaf=1, min_samples_split=2;, score=0.459 total time=   4.3s
# [CV 4/5] END max_depth=None, max_features=6, min_samples_leaf=1, min_samples_split=2;, score=0.466 total time=   4.4s
# [CV 5/5] END max_depth=None, max_features=6, min_samples_leaf=1, min_samples_split=2;, score=0.479 total time=   4.4s
# [CV 1/5] END max_depth=None, max_features=6, min_samples_leaf=1, min_samples_split=5;, score=0.482 total time=   4.0s
# [CV 2/5] END max_depth=None, max_features=6, min_samples_leaf=1, min_samples_split=5;, score=0.454 total time=   3.9s
# [CV 3/5] END max_depth=None, max_features=6, min_samples_leaf=1, min_samples_split=5;, score=0.456 total time=   4.0s
# [CV 4/5] END max_depth=None, max_features=6, min_samples_leaf=1, min_samples_split=5;, score=0.470 total time=   4.0s
# [CV 5/5] END max_depth=None, max_features=6, min_samples_leaf=1, min_samples_split=5;, score=0.479 total time=   3.9s
# [CV 1/5] END max_depth=None, max_features=6, min_samples_leaf=1, min_samples_split=10;, score=0.481 total time=   3.7s
# [CV 2/5] END max_depth=None, max_features=6, min_samples_leaf=1, min_samples_split=10;, score=0.455 total time=   3.8s
# [CV 3/5] END max_depth=None, max_features=6, min_samples_leaf=1, min_samples_split=10;, score=0.460 total time=   3.6s
# [CV 4/5] END max_depth=None, max_features=6, min_samples_leaf=1, min_samples_split=10;, score=0.469 total time=   3.7s
# [CV 5/5] END max_depth=None, max_features=6, min_samples_leaf=1, min_samples_split=10;, score=0.485 total time=   3.7s
# [CV 1/5] END max_depth=None, max_features=6, min_samples_leaf=5, min_samples_split=2;, score=0.487 total time=   2.9s
# [CV 2/5] END max_depth=None, max_features=6, min_samples_leaf=5, min_samples_split=2;, score=0.455 total time=   2.8s
# [CV 3/5] END max_depth=None, max_features=6, min_samples_leaf=5, min_samples_split=2;, score=0.464 total time=   2.8s
# [CV 4/5] END max_depth=None, max_features=6, min_samples_leaf=5, min_samples_split=2;, score=0.476 total time=   2.8s
# [CV 5/5] END max_depth=None, max_features=6, min_samples_leaf=5, min_samples_split=2;, score=0.487 total time=   2.8s
# [CV 1/5] END max_depth=None, max_features=6, min_samples_leaf=5, min_samples_split=5;, score=0.487 total time=   2.8s
# [CV 2/5] END max_depth=None, max_features=6, min_samples_leaf=5, min_samples_split=5;, score=0.455 total time=   2.9s
# [CV 3/5] END max_depth=None, max_features=6, min_samples_leaf=5, min_samples_split=5;, score=0.464 total time=   2.8s
# [CV 4/5] END max_depth=None, max_features=6, min_samples_leaf=5, min_samples_split=5;, score=0.476 total time=   2.8s
# [CV 5/5] END max_depth=None, max_features=6, min_samples_leaf=5, min_samples_split=5;, score=0.487 total time=   2.8s
# [CV 1/5] END max_depth=None, max_features=6, min_samples_leaf=5, min_samples_split=10;, score=0.487 total time=   2.8s
# [CV 2/5] END max_depth=None, max_features=6, min_samples_leaf=5, min_samples_split=10;, score=0.455 total time=   2.9s
# [CV 3/5] END max_depth=None, max_features=6, min_samples_leaf=5, min_samples_split=10;, score=0.464 total time=   2.8s
# [CV 4/5] END max_depth=None, max_features=6, min_samples_leaf=5, min_samples_split=10;, score=0.476 total time=   2.8s
# [CV 5/5] END max_depth=None, max_features=6, min_samples_leaf=5, min_samples_split=10;, score=0.487 total time=   2.8s
# [CV 1/5] END max_depth=None, max_features=6, min_samples_leaf=10, min_samples_split=2;, score=0.484 total time=   2.4s
# [CV 2/5] END max_depth=None, max_features=6, min_samples_leaf=10, min_samples_split=2;, score=0.451 total time=   2.3s
# [CV 3/5] END max_depth=None, max_features=6, min_samples_leaf=10, min_samples_split=2;, score=0.466 total time=   2.4s
# [CV 4/5] END max_depth=None, max_features=6, min_samples_leaf=10, min_samples_split=2;, score=0.472 total time=   2.4s
# [CV 5/5] END max_depth=None, max_features=6, min_samples_leaf=10, min_samples_split=2;, score=0.481 total time=   2.3s
# [CV 1/5] END max_depth=None, max_features=6, min_samples_leaf=10, min_samples_split=5;, score=0.484 total time=   2.4s
# [CV 2/5] END max_depth=None, max_features=6, min_samples_leaf=10, min_samples_split=5;, score=0.451 total time=   2.3s
# [CV 3/5] END max_depth=None, max_features=6, min_samples_leaf=10, min_samples_split=5;, score=0.466 total time=   2.3s
# [CV 4/5] END max_depth=None, max_features=6, min_samples_leaf=10, min_samples_split=5;, score=0.472 total time=   2.3s
# [CV 5/5] END max_depth=None, max_features=6, min_samples_leaf=10, min_samples_split=5;, score=0.481 total time=   2.4s
# [CV 1/5] END max_depth=None, max_features=6, min_samples_leaf=10, min_samples_split=10;, score=0.484 total time=   2.4s
# [CV 2/5] END max_depth=None, max_features=6, min_samples_leaf=10, min_samples_split=10;, score=0.451 total time=   2.3s
# [CV 3/5] END max_depth=None, max_features=6, min_samples_leaf=10, min_samples_split=10;, score=0.466 total time=   2.3s
# [CV 4/5] END max_depth=None, max_features=6, min_samples_leaf=10, min_samples_split=10;, score=0.472 total time=   2.4s
# [CV 5/5] END max_depth=None, max_features=6, min_samples_leaf=10, min_samples_split=10;, score=0.481 total time=   2.3s
# [CV 1/5] END max_depth=None, max_features=7, min_samples_leaf=1, min_samples_split=2;, score=0.476 total time=   5.1s
# [CV 2/5] END max_depth=None, max_features=7, min_samples_leaf=1, min_samples_split=2;, score=0.451 total time=   4.9s
# [CV 3/5] END max_depth=None, max_features=7, min_samples_leaf=1, min_samples_split=2;, score=0.454 total time=   4.9s
# [CV 4/5] END max_depth=None, max_features=7, min_samples_leaf=1, min_samples_split=2;, score=0.458 total time=   5.0s
# [CV 5/5] END max_depth=None, max_features=7, min_samples_leaf=1, min_samples_split=2;, score=0.475 total time=   4.9s
# [CV 1/5] END max_depth=None, max_features=7, min_samples_leaf=1, min_samples_split=5;, score=0.484 total time=   4.6s
# [CV 2/5] END max_depth=None, max_features=7, min_samples_leaf=1, min_samples_split=5;, score=0.452 total time=   4.6s
# [CV 3/5] END max_depth=None, max_features=7, min_samples_leaf=1, min_samples_split=5;, score=0.457 total time=   4.7s
# [CV 4/5] END max_depth=None, max_features=7, min_samples_leaf=1, min_samples_split=5;, score=0.467 total time=   4.9s
# [CV 5/5] END max_depth=None, max_features=7, min_samples_leaf=1, min_samples_split=5;, score=0.477 total time=   4.7s
# [CV 1/5] END max_depth=None, max_features=7, min_samples_leaf=1, min_samples_split=10;, score=0.487 total time=   4.3s
# [CV 2/5] END max_depth=None, max_features=7, min_samples_leaf=1, min_samples_split=10;, score=0.450 total time=   4.2s
# [CV 3/5] END max_depth=None, max_features=7, min_samples_leaf=1, min_samples_split=10;, score=0.457 total time=   4.2s
# [CV 4/5] END max_depth=None, max_features=7, min_samples_leaf=1, min_samples_split=10;, score=0.463 total time=   4.3s
# [CV 5/5] END max_depth=None, max_features=7, min_samples_leaf=1, min_samples_split=10;, score=0.482 total time=   4.1s
# [CV 1/5] END max_depth=None, max_features=7, min_samples_leaf=5, min_samples_split=2;, score=0.485 total time=   3.3s
# [CV 2/5] END max_depth=None, max_features=7, min_samples_leaf=5, min_samples_split=2;, score=0.453 total time=   3.3s
# [CV 3/5] END max_depth=None, max_features=7, min_samples_leaf=5, min_samples_split=2;, score=0.466 total time=   3.2s
# [CV 4/5] END max_depth=None, max_features=7, min_samples_leaf=5, min_samples_split=2;, score=0.472 total time=   3.3s
# [CV 5/5] END max_depth=None, max_features=7, min_samples_leaf=5, min_samples_split=2;, score=0.483 total time=   3.2s
# [CV 1/5] END max_depth=None, max_features=7, min_samples_leaf=5, min_samples_split=5;, score=0.485 total time=   3.3s
# [CV 2/5] END max_depth=None, max_features=7, min_samples_leaf=5, min_samples_split=5;, score=0.453 total time=   3.3s
# [CV 3/5] END max_depth=None, max_features=7, min_samples_leaf=5, min_samples_split=5;, score=0.466 total time=   3.3s
# [CV 4/5] END max_depth=None, max_features=7, min_samples_leaf=5, min_samples_split=5;, score=0.472 total time=   3.3s
# [CV 5/5] END max_depth=None, max_features=7, min_samples_leaf=5, min_samples_split=5;, score=0.483 total time=   3.2s
# [CV 1/5] END max_depth=None, max_features=7, min_samples_leaf=5, min_samples_split=10;, score=0.485 total time=   3.3s
# [CV 2/5] END max_depth=None, max_features=7, min_samples_leaf=5, min_samples_split=10;, score=0.453 total time=   3.3s
# [CV 3/5] END max_depth=None, max_features=7, min_samples_leaf=5, min_samples_split=10;, score=0.466 total time=   3.3s
# [CV 4/5] END max_depth=None, max_features=7, min_samples_leaf=5, min_samples_split=10;, score=0.472 total time=   3.3s
# [CV 5/5] END max_depth=None, max_features=7, min_samples_leaf=5, min_samples_split=10;, score=0.483 total time=   3.2s
# [CV 1/5] END max_depth=None, max_features=7, min_samples_leaf=10, min_samples_split=2;, score=0.484 total time=   2.7s
# [CV 2/5] END max_depth=None, max_features=7, min_samples_leaf=10, min_samples_split=2;, score=0.452 total time=   2.7s
# [CV 3/5] END max_depth=None, max_features=7, min_samples_leaf=10, min_samples_split=2;, score=0.466 total time=   2.7s
# [CV 4/5] END max_depth=None, max_features=7, min_samples_leaf=10, min_samples_split=2;, score=0.471 total time=   2.8s
# [CV 5/5] END max_depth=None, max_features=7, min_samples_leaf=10, min_samples_split=2;, score=0.482 total time=   2.7s
# [CV 1/5] END max_depth=None, max_features=7, min_samples_leaf=10, min_samples_split=5;, score=0.484 total time=   2.7s
# [CV 2/5] END max_depth=None, max_features=7, min_samples_leaf=10, min_samples_split=5;, score=0.452 total time=   2.7s
# [CV 3/5] END max_depth=None, max_features=7, min_samples_leaf=10, min_samples_split=5;, score=0.466 total time=   2.8s
# [CV 4/5] END max_depth=None, max_features=7, min_samples_leaf=10, min_samples_split=5;, score=0.471 total time=   2.8s
# [CV 5/5] END max_depth=None, max_features=7, min_samples_leaf=10, min_samples_split=5;, score=0.482 total time=   2.7s
# [CV 1/5] END max_depth=None, max_features=7, min_samples_leaf=10, min_samples_split=10;, score=0.484 total time=   2.7s
# [CV 2/5] END max_depth=None, max_features=7, min_samples_leaf=10, min_samples_split=10;, score=0.452 total time=   2.7s
# [CV 3/5] END max_depth=None, max_features=7, min_samples_leaf=10, min_samples_split=10;, score=0.466 total time=   2.7s
# [CV 4/5] END max_depth=None, max_features=7, min_samples_leaf=10, min_samples_split=10;, score=0.471 total time=   2.7s
# [CV 5/5] END max_depth=None, max_features=7, min_samples_leaf=10, min_samples_split=10;, score=0.482 total time=   2.8s
# [CV 1/5] END max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=2;, score=0.354 total time=   0.3s
# [CV 2/5] END max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=2;, score=0.347 total time=   0.3s
# [CV 3/5] END max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=2;, score=0.362 total time=   0.3s
# [CV 4/5] END max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=2;, score=0.330 total time=   0.3s
# [CV 5/5] END max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=2;, score=0.365 total time=   0.3s
# [CV 1/5] END max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=5;, score=0.354 total time=   0.3s
# [CV 2/5] END max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=5;, score=0.347 total time=   0.3s
# [CV 3/5] END max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=5;, score=0.362 total time=   0.3s
# [CV 4/5] END max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=5;, score=0.330 total time=   0.3s
# [CV 5/5] END max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=5;, score=0.365 total time=   0.3s
# [CV 1/5] END max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=10;, score=0.354 total time=   0.3s
# [CV 2/5] END max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=10;, score=0.347 total time=   0.3s
# [CV 3/5] END max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=10;, score=0.362 total time=   0.3s
# [CV 4/5] END max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=10;, score=0.330 total time=   0.3s
# [CV 5/5] END max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=10;, score=0.365 total time=   0.3s
# [CV 1/5] END max_depth=3, max_features=3, min_samples_leaf=5, min_samples_split=2;, score=0.354 total time=   0.3s
# [CV 2/5] END max_depth=3, max_features=3, min_samples_leaf=5, min_samples_split=2;, score=0.347 total time=   0.3s
# [CV 3/5] END max_depth=3, max_features=3, min_samples_leaf=5, min_samples_split=2;, score=0.362 total time=   0.3s
# [CV 4/5] END max_depth=3, max_features=3, min_samples_leaf=5, min_samples_split=2;, score=0.330 total time=   0.3s
# [CV 5/5] END max_depth=3, max_features=3, min_samples_leaf=5, min_samples_split=2;, score=0.364 total time=   0.3s
# [CV 1/5] END max_depth=3, max_features=3, min_samples_leaf=5, min_samples_split=5;, score=0.354 total time=   0.3s
# [CV 2/5] END max_depth=3, max_features=3, min_samples_leaf=5, min_samples_split=5;, score=0.347 total time=   0.3s
# [CV 3/5] END max_depth=3, max_features=3, min_samples_leaf=5, min_samples_split=5;, score=0.362 total time=   0.3s
# [CV 4/5] END max_depth=3, max_features=3, min_samples_leaf=5, min_samples_split=5;, score=0.330 total time=   0.3s
# [CV 5/5] END max_depth=3, max_features=3, min_samples_leaf=5, min_samples_split=5;, score=0.364 total time=   0.3s
# [CV 1/5] END max_depth=3, max_features=3, min_samples_leaf=5, min_samples_split=10;, score=0.354 total time=   0.3s
# [CV 2/5] END max_depth=3, max_features=3, min_samples_leaf=5, min_samples_split=10;, score=0.347 total time=   0.3s
# [CV 3/5] END max_depth=3, max_features=3, min_samples_leaf=5, min_samples_split=10;, score=0.362 total time=   0.3s
# [CV 4/5] END max_depth=3, max_features=3, min_samples_leaf=5, min_samples_split=10;, score=0.330 total time=   0.3s
# [CV 5/5] END max_depth=3, max_features=3, min_samples_leaf=5, min_samples_split=10;, score=0.364 total time=   0.3s
# [CV 1/5] END max_depth=3, max_features=3, min_samples_leaf=10, min_samples_split=2;, score=0.354 total time=   0.3s
# [CV 2/5] END max_depth=3, max_features=3, min_samples_leaf=10, min_samples_split=2;, score=0.347 total time=   0.3s
# [CV 3/5] END max_depth=3, max_features=3, min_samples_leaf=10, min_samples_split=2;, score=0.362 total time=   0.3s
# [CV 4/5] END max_depth=3, max_features=3, min_samples_leaf=10, min_samples_split=2;, score=0.330 total time=   0.3s
# [CV 5/5] END max_depth=3, max_features=3, min_samples_leaf=10, min_samples_split=2;, score=0.364 total time=   0.3s
# [CV 1/5] END max_depth=3, max_features=3, min_samples_leaf=10, min_samples_split=5;, score=0.354 total time=   0.3s
# [CV 2/5] END max_depth=3, max_features=3, min_samples_leaf=10, min_samples_split=5;, score=0.347 total time=   0.3s
# [CV 3/5] END max_depth=3, max_features=3, min_samples_leaf=10, min_samples_split=5;, score=0.362 total time=   0.3s
# [CV 4/5] END max_depth=3, max_features=3, min_samples_leaf=10, min_samples_split=5;, score=0.330 total time=   0.3s
# [CV 5/5] END max_depth=3, max_features=3, min_samples_leaf=10, min_samples_split=5;, score=0.364 total time=   0.3s
# [CV 1/5] END max_depth=3, max_features=3, min_samples_leaf=10, min_samples_split=10;, score=0.354 total time=   0.3s
# [CV 2/5] END max_depth=3, max_features=3, min_samples_leaf=10, min_samples_split=10;, score=0.347 total time=   0.3s
# [CV 3/5] END max_depth=3, max_features=3, min_samples_leaf=10, min_samples_split=10;, score=0.362 total time=   0.3s
# [CV 4/5] END max_depth=3, max_features=3, min_samples_leaf=10, min_samples_split=10;, score=0.330 total time=   0.4s
# [CV 5/5] END max_depth=3, max_features=3, min_samples_leaf=10, min_samples_split=10;, score=0.364 total time=   0.3s
# [CV 1/5] END max_depth=3, max_features=4, min_samples_leaf=1, min_samples_split=2;, score=0.363 total time=   0.4s
# [CV 2/5] END max_depth=3, max_features=4, min_samples_leaf=1, min_samples_split=2;, score=0.348 total time=   0.4s
# [CV 3/5] END max_depth=3, max_features=4, min_samples_leaf=1, min_samples_split=2;, score=0.366 total time=   0.4s
# [CV 4/5] END max_depth=3, max_features=4, min_samples_leaf=1, min_samples_split=2;, score=0.335 total time=   0.4s
# [CV 5/5] END max_depth=3, max_features=4, min_samples_leaf=1, min_samples_split=2;, score=0.366 total time=   0.4s
# [CV 1/5] END max_depth=3, max_features=4, min_samples_leaf=1, min_samples_split=5;, score=0.363 total time=   0.4s
# [CV 2/5] END max_depth=3, max_features=4, min_samples_leaf=1, min_samples_split=5;, score=0.348 total time=   0.4s
# [CV 3/5] END max_depth=3, max_features=4, min_samples_leaf=1, min_samples_split=5;, score=0.366 total time=   0.4s
# [CV 4/5] END max_depth=3, max_features=4, min_samples_leaf=1, min_samples_split=5;, score=0.335 total time=   0.4s
# [CV 5/5] END max_depth=3, max_features=4, min_samples_leaf=1, min_samples_split=5;, score=0.366 total time=   0.4s
# [CV 1/5] END max_depth=3, max_features=4, min_samples_leaf=1, min_samples_split=10;, score=0.363 total time=   0.4s
# [CV 2/5] END max_depth=3, max_features=4, min_samples_leaf=1, min_samples_split=10;, score=0.348 total time=   0.4s
# [CV 3/5] END max_depth=3, max_features=4, min_samples_leaf=1, min_samples_split=10;, score=0.366 total time=   0.4s
# [CV 4/5] END max_depth=3, max_features=4, min_samples_leaf=1, min_samples_split=10;, score=0.335 total time=   0.4s
# [CV 5/5] END max_depth=3, max_features=4, min_samples_leaf=1, min_samples_split=10;, score=0.366 total time=   0.4s
# [CV 1/5] END max_depth=3, max_features=4, min_samples_leaf=5, min_samples_split=2;, score=0.363 total time=   0.4s
# [CV 2/5] END max_depth=3, max_features=4, min_samples_leaf=5, min_samples_split=2;, score=0.348 total time=   0.4s
# [CV 3/5] END max_depth=3, max_features=4, min_samples_leaf=5, min_samples_split=2;, score=0.366 total time=   0.4s
# [CV 4/5] END max_depth=3, max_features=4, min_samples_leaf=5, min_samples_split=2;, score=0.335 total time=   0.4s
# [CV 5/5] END max_depth=3, max_features=4, min_samples_leaf=5, min_samples_split=2;, score=0.366 total time=   0.4s
# [CV 1/5] END max_depth=3, max_features=4, min_samples_leaf=5, min_samples_split=5;, score=0.363 total time=   0.4s
# [CV 2/5] END max_depth=3, max_features=4, min_samples_leaf=5, min_samples_split=5;, score=0.348 total time=   0.4s
# [CV 3/5] END max_depth=3, max_features=4, min_samples_leaf=5, min_samples_split=5;, score=0.366 total time=   0.4s
# [CV 4/5] END max_depth=3, max_features=4, min_samples_leaf=5, min_samples_split=5;, score=0.335 total time=   0.4s
# [CV 5/5] END max_depth=3, max_features=4, min_samples_leaf=5, min_samples_split=5;, score=0.366 total time=   0.4s
# [CV 1/5] END max_depth=3, max_features=4, min_samples_leaf=5, min_samples_split=10;, score=0.363 total time=   0.4s
# [CV 2/5] END max_depth=3, max_features=4, min_samples_leaf=5, min_samples_split=10;, score=0.348 total time=   0.4s
# [CV 3/5] END max_depth=3, max_features=4, min_samples_leaf=5, min_samples_split=10;, score=0.366 total time=   0.4s
# [CV 4/5] END max_depth=3, max_features=4, min_samples_leaf=5, min_samples_split=10;, score=0.335 total time=   0.4s
# [CV 5/5] END max_depth=3, max_features=4, min_samples_leaf=5, min_samples_split=10;, score=0.366 total time=   0.4s
# [CV 1/5] END max_depth=3, max_features=4, min_samples_leaf=10, min_samples_split=2;, score=0.363 total time=   0.4s
# [CV 2/5] END max_depth=3, max_features=4, min_samples_leaf=10, min_samples_split=2;, score=0.348 total time=   0.4s
# [CV 3/5] END max_depth=3, max_features=4, min_samples_leaf=10, min_samples_split=2;, score=0.366 total time=   0.4s
# [CV 4/5] END max_depth=3, max_features=4, min_samples_leaf=10, min_samples_split=2;, score=0.335 total time=   0.4s
# [CV 5/5] END max_depth=3, max_features=4, min_samples_leaf=10, min_samples_split=2;, score=0.366 total time=   0.4s
# [CV 1/5] END max_depth=3, max_features=4, min_samples_leaf=10, min_samples_split=5;, score=0.363 total time=   0.4s
# [CV 2/5] END max_depth=3, max_features=4, min_samples_leaf=10, min_samples_split=5;, score=0.348 total time=   0.4s
# [CV 3/5] END max_depth=3, max_features=4, min_samples_leaf=10, min_samples_split=5;, score=0.366 total time=   0.4s
# [CV 4/5] END max_depth=3, max_features=4, min_samples_leaf=10, min_samples_split=5;, score=0.335 total time=   0.4s
# [CV 5/5] END max_depth=3, max_features=4, min_samples_leaf=10, min_samples_split=5;, score=0.366 total time=   0.4s
# [CV 1/5] END max_depth=3, max_features=4, min_samples_leaf=10, min_samples_split=10;, score=0.363 total time=   0.4s
# [CV 2/5] END max_depth=3, max_features=4, min_samples_leaf=10, min_samples_split=10;, score=0.348 total time=   0.4s
# [CV 3/5] END max_depth=3, max_features=4, min_samples_leaf=10, min_samples_split=10;, score=0.366 total time=   0.4s
# [CV 4/5] END max_depth=3, max_features=4, min_samples_leaf=10, min_samples_split=10;, score=0.335 total time=   0.4s
# [CV 5/5] END max_depth=3, max_features=4, min_samples_leaf=10, min_samples_split=10;, score=0.366 total time=   0.4s
# [CV 1/5] END max_depth=3, max_features=5, min_samples_leaf=1, min_samples_split=2;, score=0.366 total time=   0.5s
# [CV 2/5] END max_depth=3, max_features=5, min_samples_leaf=1, min_samples_split=2;, score=0.350 total time=   0.5s
# [CV 3/5] END max_depth=3, max_features=5, min_samples_leaf=1, min_samples_split=2;, score=0.371 total time=   0.5s
# [CV 4/5] END max_depth=3, max_features=5, min_samples_leaf=1, min_samples_split=2;, score=0.337 total time=   0.5s
# [CV 5/5] END max_depth=3, max_features=5, min_samples_leaf=1, min_samples_split=2;, score=0.373 total time=   0.5s
# [CV 1/5] END max_depth=3, max_features=5, min_samples_leaf=1, min_samples_split=5;, score=0.366 total time=   0.5s
# [CV 2/5] END max_depth=3, max_features=5, min_samples_leaf=1, min_samples_split=5;, score=0.350 total time=   0.5s
# [CV 3/5] END max_depth=3, max_features=5, min_samples_leaf=1, min_samples_split=5;, score=0.371 total time=   0.5s
# [CV 4/5] END max_depth=3, max_features=5, min_samples_leaf=1, min_samples_split=5;, score=0.337 total time=   0.5s
# [CV 5/5] END max_depth=3, max_features=5, min_samples_leaf=1, min_samples_split=5;, score=0.373 total time=   0.5s
# [CV 1/5] END max_depth=3, max_features=5, min_samples_leaf=1, min_samples_split=10;, score=0.366 total time=   0.5s
# [CV 2/5] END max_depth=3, max_features=5, min_samples_leaf=1, min_samples_split=10;, score=0.350 total time=   0.5s
# [CV 3/5] END max_depth=3, max_features=5, min_samples_leaf=1, min_samples_split=10;, score=0.371 total time=   0.5s
# [CV 4/5] END max_depth=3, max_features=5, min_samples_leaf=1, min_samples_split=10;, score=0.337 total time=   0.5s
# [CV 5/5] END max_depth=3, max_features=5, min_samples_leaf=1, min_samples_split=10;, score=0.373 total time=   0.5s
# [CV 1/5] END max_depth=3, max_features=5, min_samples_leaf=5, min_samples_split=2;, score=0.366 total time=   0.5s
# [CV 2/5] END max_depth=3, max_features=5, min_samples_leaf=5, min_samples_split=2;, score=0.350 total time=   0.5s
# [CV 3/5] END max_depth=3, max_features=5, min_samples_leaf=5, min_samples_split=2;, score=0.371 total time=   0.5s
# [CV 4/5] END max_depth=3, max_features=5, min_samples_leaf=5, min_samples_split=2;, score=0.337 total time=   0.5s
# [CV 5/5] END max_depth=3, max_features=5, min_samples_leaf=5, min_samples_split=2;, score=0.373 total time=   0.5s
# [CV 1/5] END max_depth=3, max_features=5, min_samples_leaf=5, min_samples_split=5;, score=0.366 total time=   0.5s
# [CV 2/5] END max_depth=3, max_features=5, min_samples_leaf=5, min_samples_split=5;, score=0.350 total time=   0.5s
# [CV 3/5] END max_depth=3, max_features=5, min_samples_leaf=5, min_samples_split=5;, score=0.371 total time=   0.5s
# [CV 4/5] END max_depth=3, max_features=5, min_samples_leaf=5, min_samples_split=5;, score=0.337 total time=   0.5s
# [CV 5/5] END max_depth=3, max_features=5, min_samples_leaf=5, min_samples_split=5;, score=0.373 total time=   0.5s
# [CV 1/5] END max_depth=3, max_features=5, min_samples_leaf=5, min_samples_split=10;, score=0.366 total time=   0.5s
# [CV 2/5] END max_depth=3, max_features=5, min_samples_leaf=5, min_samples_split=10;, score=0.350 total time=   0.5s
# [CV 3/5] END max_depth=3, max_features=5, min_samples_leaf=5, min_samples_split=10;, score=0.371 total time=   0.5s
# [CV 4/5] END max_depth=3, max_features=5, min_samples_leaf=5, min_samples_split=10;, score=0.337 total time=   0.5s
# [CV 5/5] END max_depth=3, max_features=5, min_samples_leaf=5, min_samples_split=10;, score=0.373 total time=   0.5s
# [CV 1/5] END max_depth=3, max_features=5, min_samples_leaf=10, min_samples_split=2;, score=0.366 total time=   0.5s
# [CV 2/5] END max_depth=3, max_features=5, min_samples_leaf=10, min_samples_split=2;, score=0.350 total time=   0.5s
# [CV 3/5] END max_depth=3, max_features=5, min_samples_leaf=10, min_samples_split=2;, score=0.371 total time=   0.5s
# [CV 4/5] END max_depth=3, max_features=5, min_samples_leaf=10, min_samples_split=2;, score=0.337 total time=   0.5s
# [CV 5/5] END max_depth=3, max_features=5, min_samples_leaf=10, min_samples_split=2;, score=0.373 total time=   0.5s
# [CV 1/5] END max_depth=3, max_features=5, min_samples_leaf=10, min_samples_split=5;, score=0.366 total time=   0.5s
# [CV 2/5] END max_depth=3, max_features=5, min_samples_leaf=10, min_samples_split=5;, score=0.350 total time=   0.5s
# [CV 3/5] END max_depth=3, max_features=5, min_samples_leaf=10, min_samples_split=5;, score=0.371 total time=   0.5s
# [CV 4/5] END max_depth=3, max_features=5, min_samples_leaf=10, min_samples_split=5;, score=0.337 total time=   0.5s
# [CV 5/5] END max_depth=3, max_features=5, min_samples_leaf=10, min_samples_split=5;, score=0.373 total time=   0.5s
# [CV 1/5] END max_depth=3, max_features=5, min_samples_leaf=10, min_samples_split=10;, score=0.366 total time=   0.5s
# [CV 2/5] END max_depth=3, max_features=5, min_samples_leaf=10, min_samples_split=10;, score=0.350 total time=   0.5s
# [CV 3/5] END max_depth=3, max_features=5, min_samples_leaf=10, min_samples_split=10;, score=0.371 total time=   0.5s
# [CV 4/5] END max_depth=3, max_features=5, min_samples_leaf=10, min_samples_split=10;, score=0.337 total time=   0.5s
# [CV 5/5] END max_depth=3, max_features=5, min_samples_leaf=10, min_samples_split=10;, score=0.373 total time=   0.5s
# [CV 1/5] END max_depth=3, max_features=6, min_samples_leaf=1, min_samples_split=2;, score=0.365 total time=   0.5s
# [CV 2/5] END max_depth=3, max_features=6, min_samples_leaf=1, min_samples_split=2;, score=0.343 total time=   0.6s
# [CV 3/5] END max_depth=3, max_features=6, min_samples_leaf=1, min_samples_split=2;, score=0.372 total time=   0.6s
# [CV 4/5] END max_depth=3, max_features=6, min_samples_leaf=1, min_samples_split=2;, score=0.339 total time=   0.6s
# [CV 5/5] END max_depth=3, max_features=6, min_samples_leaf=1, min_samples_split=2;, score=0.373 total time=   0.6s
# [CV 1/5] END max_depth=3, max_features=6, min_samples_leaf=1, min_samples_split=5;, score=0.365 total time=   0.6s
# [CV 2/5] END max_depth=3, max_features=6, min_samples_leaf=1, min_samples_split=5;, score=0.343 total time=   0.6s
# [CV 3/5] END max_depth=3, max_features=6, min_samples_leaf=1, min_samples_split=5;, score=0.372 total time=   0.6s
# [CV 4/5] END max_depth=3, max_features=6, min_samples_leaf=1, min_samples_split=5;, score=0.339 total time=   0.5s
# [CV 5/5] END max_depth=3, max_features=6, min_samples_leaf=1, min_samples_split=5;, score=0.373 total time=   0.6s
# [CV 1/5] END max_depth=3, max_features=6, min_samples_leaf=1, min_samples_split=10;, score=0.365 total time=   0.6s
# [CV 2/5] END max_depth=3, max_features=6, min_samples_leaf=1, min_samples_split=10;, score=0.343 total time=   0.6s
# [CV 3/5] END max_depth=3, max_features=6, min_samples_leaf=1, min_samples_split=10;, score=0.372 total time=   0.5s
# [CV 4/5] END max_depth=3, max_features=6, min_samples_leaf=1, min_samples_split=10;, score=0.339 total time=   0.5s
# [CV 5/5] END max_depth=3, max_features=6, min_samples_leaf=1, min_samples_split=10;, score=0.373 total time=   0.5s
# [CV 1/5] END max_depth=3, max_features=6, min_samples_leaf=5, min_samples_split=2;, score=0.365 total time=   0.5s
# [CV 2/5] END max_depth=3, max_features=6, min_samples_leaf=5, min_samples_split=2;, score=0.343 total time=   0.6s
# [CV 3/5] END max_depth=3, max_features=6, min_samples_leaf=5, min_samples_split=2;, score=0.372 total time=   0.6s
# [CV 4/5] END max_depth=3, max_features=6, min_samples_leaf=5, min_samples_split=2;, score=0.339 total time=   0.5s
# [CV 5/5] END max_depth=3, max_features=6, min_samples_leaf=5, min_samples_split=2;, score=0.373 total time=   0.6s
# [CV 1/5] END max_depth=3, max_features=6, min_samples_leaf=5, min_samples_split=5;, score=0.365 total time=   0.5s
# [CV 2/5] END max_depth=3, max_features=6, min_samples_leaf=5, min_samples_split=5;, score=0.343 total time=   0.6s
# [CV 3/5] END max_depth=3, max_features=6, min_samples_leaf=5, min_samples_split=5;, score=0.372 total time=   0.6s
# [CV 4/5] END max_depth=3, max_features=6, min_samples_leaf=5, min_samples_split=5;, score=0.339 total time=   0.5s
# [CV 5/5] END max_depth=3, max_features=6, min_samples_leaf=5, min_samples_split=5;, score=0.373 total time=   0.6s
# [CV 1/5] END max_depth=3, max_features=6, min_samples_leaf=5, min_samples_split=10;, score=0.365 total time=   0.5s
# [CV 2/5] END max_depth=3, max_features=6, min_samples_leaf=5, min_samples_split=10;, score=0.343 total time=   0.6s
# [CV 3/5] END max_depth=3, max_features=6, min_samples_leaf=5, min_samples_split=10;, score=0.372 total time=   0.5s
# [CV 4/5] END max_depth=3, max_features=6, min_samples_leaf=5, min_samples_split=10;, score=0.339 total time=   0.6s
# [CV 5/5] END max_depth=3, max_features=6, min_samples_leaf=5, min_samples_split=10;, score=0.373 total time=   0.6s
# [CV 1/5] END max_depth=3, max_features=6, min_samples_leaf=10, min_samples_split=2;, score=0.365 total time=   0.6s
# [CV 2/5] END max_depth=3, max_features=6, min_samples_leaf=10, min_samples_split=2;, score=0.343 total time=   0.6s
# [CV 3/5] END max_depth=3, max_features=6, min_samples_leaf=10, min_samples_split=2;, score=0.372 total time=   0.6s
# [CV 4/5] END max_depth=3, max_features=6, min_samples_leaf=10, min_samples_split=2;, score=0.339 total time=   0.6s
# [CV 5/5] END max_depth=3, max_features=6, min_samples_leaf=10, min_samples_split=2;, score=0.373 total time=   0.6s
# [CV 1/5] END max_depth=3, max_features=6, min_samples_leaf=10, min_samples_split=5;, score=0.365 total time=   0.6s
# [CV 2/5] END max_depth=3, max_features=6, min_samples_leaf=10, min_samples_split=5;, score=0.343 total time=   0.6s
# [CV 3/5] END max_depth=3, max_features=6, min_samples_leaf=10, min_samples_split=5;, score=0.372 total time=   0.6s
# [CV 4/5] END max_depth=3, max_features=6, min_samples_leaf=10, min_samples_split=5;, score=0.339 total time=   0.5s
# [CV 5/5] END max_depth=3, max_features=6, min_samples_leaf=10, min_samples_split=5;, score=0.373 total time=   0.6s
# [CV 1/5] END max_depth=3, max_features=6, min_samples_leaf=10, min_samples_split=10;, score=0.365 total time=   0.6s
# [CV 2/5] END max_depth=3, max_features=6, min_samples_leaf=10, min_samples_split=10;, score=0.343 total time=   0.6s
# [CV 3/5] END max_depth=3, max_features=6, min_samples_leaf=10, min_samples_split=10;, score=0.372 total time=   0.6s
# [CV 4/5] END max_depth=3, max_features=6, min_samples_leaf=10, min_samples_split=10;, score=0.339 total time=   0.6s
# [CV 5/5] END max_depth=3, max_features=6, min_samples_leaf=10, min_samples_split=10;, score=0.373 total time=   0.6s
# [CV 1/5] END max_depth=3, max_features=7, min_samples_leaf=1, min_samples_split=2;, score=0.368 total time=   0.6s
# [CV 2/5] END max_depth=3, max_features=7, min_samples_leaf=1, min_samples_split=2;, score=0.342 total time=   0.7s
# [CV 3/5] END max_depth=3, max_features=7, min_samples_leaf=1, min_samples_split=2;, score=0.373 total time=   0.7s
# ...
# [CV 4/5] END max_depth=5, max_features=4, min_samples_leaf=10, min_samples_split=10;, score=0.394 total time=   0.7s
# [CV 5/5] END max_depth=5, max_features=4, min_samples_leaf=10, min_samples_split=10;, score=0.421 total time=   0.6s
# [CV 1/5] END max_depth=5, max_features=5, min_samples_leaf=1, min_samples_split=2;, score=0.418 total time=   0.8s
# [CV 2/5] END max_depth=5, max_features=5, min_samples_leaf=1, min_samples_split=2;, score=0.400 total time=   0.8s
# [CV 3/5] END max_depth=5, max_features=5, min_samples_leaf=1, min_samples_split=2;, score=0.418 total time=   0.8s
# [CV 4/5] END max_depth=5, max_features=5, min_samples_leaf=1, min_samples_split=2;, score=0.397 total time=   0.8s
# [CV 5/5] END max_depth=5, max_features=5, min_samples_leaf=1, min_samples_split=2;, score=0.425 total time=   0.8s
# [CV 1/5] END max_depth=5, max_features=5, min_samples_leaf=1, min_samples_split=5;, score=0.419 total time=   0.8s
# [CV 2/5] END max_depth=5, max_features=5, min_samples_leaf=1, min_samples_split=5;, score=0.400 total time=   0.8s
# [CV 3/5] END max_depth=5, max_features=5, min_samples_leaf=1, min_samples_split=5;, score=0.417 total time=   0.8s
# [CV 4/5] END max_depth=5, max_features=5, min_samples_leaf=1, min_samples_split=5;, score=0.398 total time=   0.8s
# [CV 5/5] END max_depth=5, max_features=5, min_samples_leaf=1, min_samples_split=5;, score=0.425 total time=   0.8s
# [CV 1/5] END max_depth=5, max_features=5, min_samples_leaf=1, min_samples_split=10;, score=0.419 total time=   0.8s
# [CV 2/5] END max_depth=5, max_features=5, min_samples_leaf=1, min_samples_split=10;, score=0.400 total time=   0.8s
# [CV 3/5] END max_depth=5, max_features=5, min_samples_leaf=1, min_samples_split=10;, score=0.418 total time=   0.8s
# [CV 4/5] END max_depth=5, max_features=5, min_samples_leaf=1, min_samples_split=10;, score=0.398 total time=   0.8s
# [CV 5/5] END max_depth=5, max_features=5, min_samples_leaf=1, min_samples_split=10;, score=0.425 total time=   0.8s
# [CV 1/5] END max_depth=5, max_features=5, min_samples_leaf=5, min_samples_split=2;, score=0.419 total time=   0.8s
# [CV 2/5] END max_depth=5, max_features=5, min_samples_leaf=5, min_samples_split=2;, score=0.400 total time=   0.8s
# [CV 3/5] END max_depth=5, max_features=5, min_samples_leaf=5, min_samples_split=2;, score=0.417 total time=   0.8s
# [CV 4/5] END max_depth=5, max_features=5, min_samples_leaf=5, min_samples_split=2;, score=0.399 total time=   0.8s
# [CV 5/5] END max_depth=5, max_features=5, min_samples_leaf=5, min_samples_split=2;, score=0.426 total time=   0.8s
# [CV 1/5] END max_depth=5, max_features=5, min_samples_leaf=5, min_samples_split=5;, score=0.419 total time=   0.8s
# [CV 2/5] END max_depth=5, max_features=5, min_samples_leaf=5, min_samples_split=5;, score=0.400 total time=   0.8s
# [CV 3/5] END max_depth=5, max_features=5, min_samples_leaf=5, min_samples_split=5;, score=0.417 total time=   0.8s
# [CV 4/5] END max_depth=5, max_features=5, min_samples_leaf=5, min_samples_split=5;, score=0.399 total time=   0.8s
# [CV 5/5] END max_depth=5, max_features=5, min_samples_leaf=5, min_samples_split=5;, score=0.426 total time=   0.8s
# [CV 1/5] END max_depth=5, max_features=5, min_samples_leaf=5, min_samples_split=10;, score=0.419 total time=   0.8s
# [CV 2/5] END max_depth=5, max_features=5, min_samples_leaf=5, min_samples_split=10;, score=0.400 total time=   0.8s
# [CV 3/5] END max_depth=5, max_features=5, min_samples_leaf=5, min_samples_split=10;, score=0.417 total time=   0.8s
# [CV 4/5] END max_depth=5, max_features=5, min_samples_leaf=5, min_samples_split=10;, score=0.399 total time=   0.8s
# [CV 5/5] END max_depth=5, max_features=5, min_samples_leaf=5, min_samples_split=10;, score=0.426 total time=   0.8s
# [CV 1/5] END max_depth=5, max_features=5, min_samples_leaf=10, min_samples_split=2;, score=0.419 total time=   0.8s
# [CV 2/5] END max_depth=5, max_features=5, min_samples_leaf=10, min_samples_split=2;, score=0.401 total time=   0.8s
# [CV 3/5] END max_depth=5, max_features=5, min_samples_leaf=10, min_samples_split=2;, score=0.417 total time=   0.8s
# [CV 4/5] END max_depth=5, max_features=5, min_samples_leaf=10, min_samples_split=2;, score=0.399 total time=   0.7s
# [CV 5/5] END max_depth=5, max_features=5, min_samples_leaf=10, min_samples_split=2;, score=0.425 total time=   0.8s
# [CV 1/5] END max_depth=5, max_features=5, min_samples_leaf=10, min_samples_split=5;, score=0.419 total time=   0.8s
# [CV 2/5] END max_depth=5, max_features=5, min_samples_leaf=10, min_samples_split=5;, score=0.401 total time=   0.8s
# [CV 3/5] END max_depth=5, max_features=5, min_samples_leaf=10, min_samples_split=5;, score=0.417 total time=   0.8s
# [CV 4/5] END max_depth=5, max_features=5, min_samples_leaf=10, min_samples_split=5;, score=0.399 total time=   0.7s
# [CV 5/5] END max_depth=5, max_features=5, min_samples_leaf=10, min_samples_split=5;, score=0.425 total time=   0.8s
# [CV 1/5] END max_depth=5, max_features=5, min_samples_leaf=10, min_samples_split=10;, score=0.419 total time=   0.8s
# [CV 2/5] END max_depth=5, max_features=5, min_samples_leaf=10, min_samples_split=10;, score=0.401 total time=   0.8s
# [CV 3/5] END max_depth=5, max_features=5, min_samples_leaf=10, min_samples_split=10;, score=0.417 total time=   0.8s
# [CV 4/5] END max_depth=5, max_features=5, min_samples_leaf=10, min_samples_split=10;, score=0.399 total time=   0.7s
# [CV 5/5] END max_depth=5, max_features=5, min_samples_leaf=10, min_samples_split=10;, score=0.425 total time=   0.8s
# [CV 1/5] END max_depth=5, max_features=6, min_samples_leaf=1, min_samples_split=2;, score=0.421 total time=   0.9s
# [CV 2/5] END max_depth=5, max_features=6, min_samples_leaf=1, min_samples_split=2;, score=0.397 total time=   0.9s
# [CV 3/5] END max_depth=5, max_features=6, min_samples_leaf=1, min_samples_split=2;, score=0.420 total time=   0.9s
# [CV 4/5] END max_depth=5, max_features=6, min_samples_leaf=1, min_samples_split=2;, score=0.400 total time=   0.9s
# [CV 5/5] END max_depth=5, max_features=6, min_samples_leaf=1, min_samples_split=2;, score=0.427 total time=   0.9s
# [CV 1/5] END max_depth=5, max_features=6, min_samples_leaf=1, min_samples_split=5;, score=0.421 total time=   0.9s
# [CV 2/5] END max_depth=5, max_features=6, min_samples_leaf=1, min_samples_split=5;, score=0.397 total time=   1.0s
# [CV 3/5] END max_depth=5, max_features=6, min_samples_leaf=1, min_samples_split=5;, score=0.421 total time=   1.0s
# [CV 4/5] END max_depth=5, max_features=6, min_samples_leaf=1, min_samples_split=5;, score=0.401 total time=   1.0s
# [CV 5/5] END max_depth=5, max_features=6, min_samples_leaf=1, min_samples_split=5;, score=0.428 total time=   0.9s
# [CV 1/5] END max_depth=5, max_features=6, min_samples_leaf=1, min_samples_split=10;, score=0.420 total time=   0.9s
# [CV 2/5] END max_depth=5, max_features=6, min_samples_leaf=1, min_samples_split=10;, score=0.398 total time=   0.9s
# [CV 3/5] END max_depth=5, max_features=6, min_samples_leaf=1, min_samples_split=10;, score=0.420 total time=   0.9s
# [CV 4/5] END max_depth=5, max_features=6, min_samples_leaf=1, min_samples_split=10;, score=0.400 total time=   0.9s
# [CV 5/5] END max_depth=5, max_features=6, min_samples_leaf=1, min_samples_split=10;, score=0.427 total time=   0.9s
# [CV 1/5] END max_depth=5, max_features=6, min_samples_leaf=5, min_samples_split=2;, score=0.421 total time=   0.9s
# [CV 2/5] END max_depth=5, max_features=6, min_samples_leaf=5, min_samples_split=2;, score=0.399 total time=   0.9s
# [CV 3/5] END max_depth=5, max_features=6, min_samples_leaf=5, min_samples_split=2;, score=0.421 total time=   0.9s
# [CV 4/5] END max_depth=5, max_features=6, min_samples_leaf=5, min_samples_split=2;, score=0.401 total time=   0.9s
# [CV 5/5] END max_depth=5, max_features=6, min_samples_leaf=5, min_samples_split=2;, score=0.427 total time=   0.9s
# [CV 1/5] END max_depth=5, max_features=6, min_samples_leaf=5, min_samples_split=5;, score=0.421 total time=   0.9s
# [CV 2/5] END max_depth=5, max_features=6, min_samples_leaf=5, min_samples_split=5;, score=0.399 total time=   0.9s
# [CV 3/5] END max_depth=5, max_features=6, min_samples_leaf=5, min_samples_split=5;, score=0.421 total time=   0.9s
# [CV 4/5] END max_depth=5, max_features=6, min_samples_leaf=5, min_samples_split=5;, score=0.401 total time=   0.9s
# [CV 5/5] END max_depth=5, max_features=6, min_samples_leaf=5, min_samples_split=5;, score=0.427 total time=   0.9s
# [CV 1/5] END max_depth=5, max_features=6, min_samples_leaf=5, min_samples_split=10;, score=0.421 total time=   0.9s
# [CV 2/5] END max_depth=5, max_features=6, min_samples_leaf=5, min_samples_split=10;, score=0.399 total time=   0.9s
# [CV 3/5] END max_depth=5, max_features=6, min_samples_leaf=5, min_samples_split=10;, score=0.421 total time=   0.9s
# [CV 4/5] END max_depth=5, max_features=6, min_samples_leaf=5, min_samples_split=10;, score=0.401 total time=   0.9s
# [CV 5/5] END max_depth=5, max_features=6, min_samples_leaf=5, min_samples_split=10;, score=0.427 total time=   0.9s
# [CV 1/5] END max_depth=5, max_features=6, min_samples_leaf=10, min_samples_split=2;, score=0.421 total time=   0.9s
# [CV 2/5] END max_depth=5, max_features=6, min_samples_leaf=10, min_samples_split=2;, score=0.399 total time=   0.9s
# [CV 3/5] END max_depth=5, max_features=6, min_samples_leaf=10, min_samples_split=2;, score=0.422 total time=   0.9s
# [CV 4/5] END max_depth=5, max_features=6, min_samples_leaf=10, min_samples_split=2;, score=0.401 total time=   0.9s
# [CV 5/5] END max_depth=5, max_features=6, min_samples_leaf=10, min_samples_split=2;, score=0.427 total time=   0.9s
# [CV 1/5] END max_depth=5, max_features=6, min_samples_leaf=10, min_samples_split=5;, score=0.421 total time=   1.0s
# [CV 2/5] END max_depth=5, max_features=6, min_samples_leaf=10, min_samples_split=5;, score=0.399 total time=   0.9s
# [CV 3/5] END max_depth=5, max_features=6, min_samples_leaf=10, min_samples_split=5;, score=0.422 total time=   0.9s
# [CV 4/5] END max_depth=5, max_features=6, min_samples_leaf=10, min_samples_split=5;, score=0.401 total time=   1.0s
# [CV 5/5] END max_depth=5, max_features=6, min_samples_leaf=10, min_samples_split=5;, score=0.427 total time=   0.9s
# [CV 1/5] END max_depth=5, max_features=6, min_samples_leaf=10, min_samples_split=10;, score=0.421 total time=   0.9s
# [CV 2/5] END max_depth=5, max_features=6, min_samples_leaf=10, min_samples_split=10;, score=0.399 total time=   0.9s
# [CV 3/5] END max_depth=5, max_features=6, min_samples_leaf=10, min_samples_split=10;, score=0.422 total time=   0.9s
# [CV 4/5] END max_depth=5, max_features=6, min_samples_leaf=10, min_samples_split=10;, score=0.401 total time=   1.0s
# [CV 5/5] END max_depth=5, max_features=6, min_samples_leaf=10, min_samples_split=10;, score=0.427 total time=   0.9s
# [CV 1/5] END max_depth=5, max_features=7, min_samples_leaf=1, min_samples_split=2;, score=0.422 total time=   1.1s
# [CV 2/5] END max_depth=5, max_features=7, min_samples_leaf=1, min_samples_split=2;, score=0.395 total time=   1.1s
# [CV 3/5] END max_depth=5, max_features=7, min_samples_leaf=1, min_samples_split=2;, score=0.419 total time=   1.1s
# [CV 4/5] END max_depth=5, max_features=7, min_samples_leaf=1, min_samples_split=2;, score=0.402 total time=   1.1s
# [CV 5/5] END max_depth=5, max_features=7, min_samples_leaf=1, min_samples_split=2;, score=0.428 total time=   1.1s
# [CV 1/5] END max_depth=5, max_features=7, min_samples_leaf=1, min_samples_split=5;, score=0.422 total time=   1.0s
# [CV 2/5] END max_depth=5, max_features=7, min_samples_leaf=1, min_samples_split=5;, score=0.395 total time=   1.1s
# [CV 3/5] END max_depth=5, max_features=7, min_samples_leaf=1, min_samples_split=5;, score=0.418 total time=   1.1s
# [CV 4/5] END max_depth=5, max_features=7, min_samples_leaf=1, min_samples_split=5;, score=0.402 total time=   1.1s
# [CV 5/5] END max_depth=5, max_features=7, min_samples_leaf=1, min_samples_split=5;, score=0.428 total time=   1.1s
# [CV 1/5] END max_depth=5, max_features=7, min_samples_leaf=1, min_samples_split=10;, score=0.422 total time=   1.1s
# [CV 2/5] END max_depth=5, max_features=7, min_samples_leaf=1, min_samples_split=10;, score=0.396 total time=   1.1s
# [CV 3/5] END max_depth=5, max_features=7, min_samples_leaf=1, min_samples_split=10;, score=0.418 total time=   1.1s
# [CV 4/5] END max_depth=5, max_features=7, min_samples_leaf=1, min_samples_split=10;, score=0.402 total time=   1.1s
# [CV 5/5] END max_depth=5, max_features=7, min_samples_leaf=1, min_samples_split=10;, score=0.428 total time=   1.1s
# [CV 1/5] END max_depth=5, max_features=7, min_samples_leaf=5, min_samples_split=2;, score=0.422 total time=   1.0s
# [CV 2/5] END max_depth=5, max_features=7, min_samples_leaf=5, min_samples_split=2;, score=0.398 total time=   1.1s
# [CV 3/5] END max_depth=5, max_features=7, min_samples_leaf=5, min_samples_split=2;, score=0.419 total time=   1.0s
# [CV 4/5] END max_depth=5, max_features=7, min_samples_leaf=5, min_samples_split=2;, score=0.403 total time=   1.0s
# [CV 5/5] END max_depth=5, max_features=7, min_samples_leaf=5, min_samples_split=2;, score=0.429 total time=   1.0s
# [CV 1/5] END max_depth=5, max_features=7, min_samples_leaf=5, min_samples_split=5;, score=0.422 total time=   1.1s
# [CV 2/5] END max_depth=5, max_features=7, min_samples_leaf=5, min_samples_split=5;, score=0.398 total time=   1.1s
# [CV 3/5] END max_depth=5, max_features=7, min_samples_leaf=5, min_samples_split=5;, score=0.419 total time=   1.1s
# [CV 4/5] END max_depth=5, max_features=7, min_samples_leaf=5, min_samples_split=5;, score=0.403 total time=   1.0s
# [CV 5/5] END max_depth=5, max_features=7, min_samples_leaf=5, min_samples_split=5;, score=0.429 total time=   1.0s
# [CV 1/5] END max_depth=5, max_features=7, min_samples_leaf=5, min_samples_split=10;, score=0.422 total time=   1.1s
# [CV 2/5] END max_depth=5, max_features=7, min_samples_leaf=5, min_samples_split=10;, score=0.398 total time=   1.1s
# [CV 3/5] END max_depth=5, max_features=7, min_samples_leaf=5, min_samples_split=10;, score=0.419 total time=   1.1s
# [CV 4/5] END max_depth=5, max_features=7, min_samples_leaf=5, min_samples_split=10;, score=0.403 total time=   1.0s
# [CV 5/5] END max_depth=5, max_features=7, min_samples_leaf=5, min_samples_split=10;, score=0.429 total time=   1.0s
# [CV 1/5] END max_depth=5, max_features=7, min_samples_leaf=10, min_samples_split=2;, score=0.422 total time=   1.0s
# [CV 2/5] END max_depth=5, max_features=7, min_samples_leaf=10, min_samples_split=2;, score=0.399 total time=   1.0s
# [CV 3/5] END max_depth=5, max_features=7, min_samples_leaf=10, min_samples_split=2;, score=0.420 total time=   1.0s
# [CV 4/5] END max_depth=5, max_features=7, min_samples_leaf=10, min_samples_split=2;, score=0.402 total time=   1.0s
# [CV 5/5] END max_depth=5, max_features=7, min_samples_leaf=10, min_samples_split=2;, score=0.429 total time=   1.1s
# [CV 1/5] END max_depth=5, max_features=7, min_samples_leaf=10, min_samples_split=5;, score=0.422 total time=   1.1s
# [CV 2/5] END max_depth=5, max_features=7, min_samples_leaf=10, min_samples_split=5;, score=0.399 total time=   1.1s
# [CV 3/5] END max_depth=5, max_features=7, min_samples_leaf=10, min_samples_split=5;, score=0.420 total time=   1.0s
# [CV 4/5] END max_depth=5, max_features=7, min_samples_leaf=10, min_samples_split=5;, score=0.402 total time=   1.0s
# [CV 5/5] END max_depth=5, max_features=7, min_samples_leaf=10, min_samples_split=5;, score=0.429 total time=   1.0s
# [CV 1/5] END max_depth=5, max_features=7, min_samples_leaf=10, min_samples_split=10;, score=0.422 total time=   1.0s
# [CV 2/5] END max_depth=5, max_features=7, min_samples_leaf=10, min_samples_split=10;, score=0.399 total time=   1.0s
# [CV 3/5] END max_depth=5, max_features=7, min_samples_leaf=10, min_samples_split=10;, score=0.420 total time=   1.0s
# [CV 4/5] END max_depth=5, max_features=7, min_samples_leaf=10, min_samples_split=10;, score=0.402 total time=   1.1s
# [CV 5/5] END max_depth=5, max_features=7, min_samples_leaf=10, min_samples_split=10;, score=0.429 total time=   1.0s
# {'max_depth': None, 'max_features': 3, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.4742298424264163

# %%
best_model = gcv.best_estimator_


test_data = pd.read_csv("test.csv")

pred_berry = best_model.predict(test_data)


submit = pd.read_csv("sample_submission.csv")


submit['Hardness'] = pred_berry

# Save the submission file with the predicted hardness values
submit.to_csv("D:\\kaggla_comp\\hardness\\random_forest_hard_25.csv", index=False)
