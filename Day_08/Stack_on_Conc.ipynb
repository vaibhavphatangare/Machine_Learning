# %%
# Import necessary libraries
from sklearn.linear_model import Ridge, LinearRegression, LogisticRegression
from sklearn.metrics import accuracy_score,log_loss
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import GridSearchCV,train_test_split ,StratifiedKFold,KFold
from sklearn.svm import SVC
from xgboost import XGBClassifier,XGBRFRegressor,XGBRegressor
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.tree import DecisionTreeClassifier,DecisionTreeRegressor,ExtraTreeClassifier
from sklearn.ensemble import VotingClassifier, BaggingClassifier,BaggingRegressor,RandomForestClassifier,AdaBoostClassifier,StackingClassifier,StackingRegressor
from sklearn.neighbors import KNeighborsClassifier,KNeighborsRegressor
from sklearn.svm import SVC
from sklearn.pipeline import *
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import warnings
import os

warnings.simplefilter('ignore')
os.chdir('D:\Datasets')

conc = pd.read_csv('Concrete_Data.csv')
conc
# Out:
#       Cement  Blast    Fly  Water  Superplasticizer  Coarse   Fine  Age  \
# 0      540.0    0.0    0.0  162.0               2.5  1040.0  676.0   28
# 1      540.0    0.0    0.0  162.0               2.5  1055.0  676.0   28
# 2      332.5  142.5    0.0  228.0               0.0   932.0  594.0  270
# 3      332.5  142.5    0.0  228.0               0.0   932.0  594.0  365
# 4      198.6  132.4    0.0  192.0               0.0   978.4  825.5  360
# ...      ...    ...    ...    ...               ...     ...    ...  ...
# 1025   276.4  116.0   90.3  179.6               8.9   870.1  768.3   28
# 1026   322.2    0.0  115.6  196.0              10.4   817.9  813.4   28
# 1027   148.5  139.4  108.6  192.7               6.1   892.4  780.0   28
# 1028   159.1  186.7    0.0  175.6              11.3   989.6  788.9   28
# 1029   260.9  100.5   78.3  200.6               8.6   864.5  761.5   28
#
#       Strength
# 0        79.99
# 1        61.89
# 2        40.27
# 3        41.05
# 4        44.30
# ...        ...
# 1025     44.28
# 1026     31.18
# 1027     23.70
# 1028     32.77
# 1029     32.40
#
# [1030 rows x 9 columns]

# %%
x= conc.drop('Strength',axis=1)
y=conc['Strength']

# %%
# Create instances of the base regressors
lr = LinearRegression()
knn = KNeighborsRegressor()
xgbm = XGBRegressor(random_state=24)
dtc = DecisionTreeRegressor(random_state=24)

# Create the Stacking Regressor
# The base regressors are passed as a list of tuples, where the first element is the name of the regressor and the second is the regressor object
# The final_estimator is the XGBoost Regressor
# 'passthrough=True' means the input features will be passed to the final estimator
stack = StackingRegressor([('LR', lr), ('KNN', knn), ('TREE', dtc)], final_estimator=xgbm, passthrough=True)

# %%
print(stack.get_params())
# Out:
# {'cv': None, 'estimators': [('LR', LinearRegression()), ('KNN', KNeighborsRegressor()), ('TREE', DecisionTreeRegressor(random_state=24))], 'final_estimator__objective': 'reg:squarederror', 'final_estimator__base_score': None, 'final_estimator__booster': None, 'final_estimator__callbacks': None, 'final_estimator__colsample_bylevel': None, 'final_estimator__colsample_bynode': None, 'final_estimator__colsample_bytree': None, 'final_estimator__device': None, 'final_estimator__early_stopping_rounds': None, 'final_estimator__enable_categorical': False, 'final_estimator__eval_metric': None, 'final_estimator__feature_types': None, 'final_estimator__gamma': None, 'final_estimator__grow_policy': None, 'final_estimator__importance_type': None, 'final_estimator__interaction_constraints': None, 'final_estimator__learning_rate': None, 'final_estimator__max_bin': None, 'final_estimator__max_cat_threshold': None, 'final_estimator__max_cat_to_onehot': None, 'final_estimator__max_delta_step': None, 'final_estimator__max_depth': None, 'final_estimator__max_leaves': None, 'final_estimator__min_child_weight': None, 'final_estimator__missing': nan, 'final_estimator__monotone_constraints': None, 'final_estimator__multi_strategy': None, 'final_estimator__n_estimators': None, 'final_estimator__n_jobs': None, 'final_estimator__num_parallel_tree': None, 'final_estimator__random_state': None, 'final_estimator__reg_alpha': None, 'final_estimator__reg_lambda': None, 'final_estimator__sampling_method': None, 'final_estimator__scale_pos_weight': None, 'final_estimator__subsample': None, 'final_estimator__tree_method': None, 'final_estimator__validate_parameters': None, 'final_estimator__verbosity': None, 'final_estimator': XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...), 'n_jobs': None, 'passthrough': True, 'verbose': 0, 'LR': LinearRegression(), 'KNN': KNeighborsRegressor(), 'TREE': DecisionTreeRegressor(random_state=24), 'LR__copy_X': True, 'LR__fit_intercept': True, 'LR__n_jobs': None, 'LR__positive': False, 'KNN__algorithm': 'auto', 'KNN__leaf_size': 30, 'KNN__metric': 'minkowski', 'KNN__metric_params': None, 'KNN__n_jobs': None, 'KNN__n_neighbors': 5, 'KNN__p': 2, 'KNN__weights': 'uniform', 'TREE__ccp_alpha': 0.0, 'TREE__criterion': 'squared_error', 'TREE__max_depth': None, 'TREE__max_features': None, 'TREE__max_leaf_nodes': None, 'TREE__min_impurity_decrease': 0.0, 'TREE__min_samples_leaf': 1, 'TREE__min_samples_split': 2, 'TREE__min_weight_fraction_leaf': 0.0, 'TREE__random_state': 24, 'TREE__splitter': 'best'}

# %% [markdown]
# # Hyperparameter Tuning for Stacking Regressor

# %%
# Create a K-Fold cross-validation object
# This will split the data into 5 folds, without preserving the class distribution
# 'shuffle=True' ensures the data is shuffled before splitting
# 'random_state=24' sets the random seed for reproducibility
kfold = KFold(n_splits=5, shuffle=True, random_state=24)

# Define the hyperparameter grid to search over
# The parameters are specified for the final estimator (XGBoost Regressor) and the base regressors (KNN and Decision Tree)
params = {
    'final_estimator__learning_rate': [0.1, 0.3, 0.5],
    'final_estimator__max_depth': [1, 3, 5],
    'final_estimator__n_estimators': [25, 50],
    'KNN__n_neighbors': [3, 5, 9],
    'TREE__max_depth': [None, 3]
}

# Create a GridSearchCV object
# This will perform a grid search to find the best combination of hyperparameters
# 'cv=kfold' uses the K-Fold cross-validation object
# 'verbose=3' sets the verbosity level to 3, which will print progress updates
gcv = GridSearchCV(stack, param_grid=params, cv=kfold, verbose=3)

# Fit the GridSearchCV object to the data
# This will perform the grid search and find the best hyperparameters
gcv.fit(x, y)

# Print the best parameters found by the GridSearchCV
print("Best Parameters:", gcv.best_params_)

# Print the best score (i.e., the lowest mean squared error) found during the grid search
print("Best Score:", gcv.best_score_)

# Get the best model from the GridSearchCV object
best_model = gcv.best_estimator_
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# [CV 1/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.1, final_estimator__max_depth=1, final_estimator__n_estimators=25;, score=0.742 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.1, final_estimator__max_depth=1, final_estimator__n_estimators=25;, score=0.722 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.1, final_estimator__max_depth=1, final_estimator__n_estimators=25;, score=0.711 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.1, final_estimator__max_depth=1, final_estimator__n_estimators=25;, score=0.664 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.1, final_estimator__max_depth=1, final_estimator__n_estimators=25;, score=0.734 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.1, final_estimator__max_depth=1, final_estimator__n_estimators=50;, score=0.817 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.1, final_estimator__max_depth=1, final_estimator__n_estimators=50;, score=0.799 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.1, final_estimator__max_depth=1, final_estimator__n_estimators=50;, score=0.823 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.1, final_estimator__max_depth=1, final_estimator__n_estimators=50;, score=0.771 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.1, final_estimator__max_depth=1, final_estimator__n_estimators=50;, score=0.823 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.1, final_estimator__max_depth=3, final_estimator__n_estimators=25;, score=0.851 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.1, final_estimator__max_depth=3, final_estimator__n_estimators=25;, score=0.830 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.1, final_estimator__max_depth=3, final_estimator__n_estimators=25;, score=0.864 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.1, final_estimator__max_depth=3, final_estimator__n_estimators=25;, score=0.821 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.1, final_estimator__max_depth=3, final_estimator__n_estimators=25;, score=0.864 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.1, final_estimator__max_depth=3, final_estimator__n_estimators=50;, score=0.887 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.1, final_estimator__max_depth=3, final_estimator__n_estimators=50;, score=0.871 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.1, final_estimator__max_depth=3, final_estimator__n_estimators=50;, score=0.898 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.1, final_estimator__max_depth=3, final_estimator__n_estimators=50;, score=0.878 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.1, final_estimator__max_depth=3, final_estimator__n_estimators=50;, score=0.890 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.1, final_estimator__max_depth=5, final_estimator__n_estimators=25;, score=0.857 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.1, final_estimator__max_depth=5, final_estimator__n_estimators=25;, score=0.838 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.1, final_estimator__max_depth=5, final_estimator__n_estimators=25;, score=0.893 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.1, final_estimator__max_depth=5, final_estimator__n_estimators=25;, score=0.857 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.1, final_estimator__max_depth=5, final_estimator__n_estimators=25;, score=0.887 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.1, final_estimator__max_depth=5, final_estimator__n_estimators=50;, score=0.881 total time=   0.1s
# [CV 2/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.1, final_estimator__max_depth=5, final_estimator__n_estimators=50;, score=0.869 total time=   0.1s
# [CV 3/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.1, final_estimator__max_depth=5, final_estimator__n_estimators=50;, score=0.916 total time=   0.1s
# [CV 4/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.1, final_estimator__max_depth=5, final_estimator__n_estimators=50;, score=0.889 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.1, final_estimator__max_depth=5, final_estimator__n_estimators=50;, score=0.912 total time=   0.1s
# [CV 1/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.3, final_estimator__max_depth=1, final_estimator__n_estimators=25;, score=0.833 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.3, final_estimator__max_depth=1, final_estimator__n_estimators=25;, score=0.814 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.3, final_estimator__max_depth=1, final_estimator__n_estimators=25;, score=0.856 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.3, final_estimator__max_depth=1, final_estimator__n_estimators=25;, score=0.801 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.3, final_estimator__max_depth=1, final_estimator__n_estimators=25;, score=0.843 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.3, final_estimator__max_depth=1, final_estimator__n_estimators=50;, score=0.858 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.3, final_estimator__max_depth=1, final_estimator__n_estimators=50;, score=0.832 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.3, final_estimator__max_depth=1, final_estimator__n_estimators=50;, score=0.876 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.3, final_estimator__max_depth=1, final_estimator__n_estimators=50;, score=0.829 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.3, final_estimator__max_depth=1, final_estimator__n_estimators=50;, score=0.860 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.3, final_estimator__max_depth=3, final_estimator__n_estimators=25;, score=0.890 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.3, final_estimator__max_depth=3, final_estimator__n_estimators=25;, score=0.863 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.3, final_estimator__max_depth=3, final_estimator__n_estimators=25;, score=0.903 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.3, final_estimator__max_depth=3, final_estimator__n_estimators=25;, score=0.881 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.3, final_estimator__max_depth=3, final_estimator__n_estimators=25;, score=0.882 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.3, final_estimator__max_depth=3, final_estimator__n_estimators=50;, score=0.906 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.3, final_estimator__max_depth=3, final_estimator__n_estimators=50;, score=0.870 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.3, final_estimator__max_depth=3, final_estimator__n_estimators=50;, score=0.913 total time=   0.1s
# [CV 4/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.3, final_estimator__max_depth=3, final_estimator__n_estimators=50;, score=0.893 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.3, final_estimator__max_depth=3, final_estimator__n_estimators=50;, score=0.896 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.3, final_estimator__max_depth=5, final_estimator__n_estimators=25;, score=0.881 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.3, final_estimator__max_depth=5, final_estimator__n_estimators=25;, score=0.863 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.3, final_estimator__max_depth=5, final_estimator__n_estimators=25;, score=0.920 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.3, final_estimator__max_depth=5, final_estimator__n_estimators=25;, score=0.898 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.3, final_estimator__max_depth=5, final_estimator__n_estimators=25;, score=0.895 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.3, final_estimator__max_depth=5, final_estimator__n_estimators=50;, score=0.889 total time=   0.1s
# [CV 2/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.3, final_estimator__max_depth=5, final_estimator__n_estimators=50;, score=0.868 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.3, final_estimator__max_depth=5, final_estimator__n_estimators=50;, score=0.925 total time=   0.1s
# [CV 4/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.3, final_estimator__max_depth=5, final_estimator__n_estimators=50;, score=0.905 total time=   0.1s
# [CV 5/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.3, final_estimator__max_depth=5, final_estimator__n_estimators=50;, score=0.901 total time=   0.1s
# [CV 1/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.5, final_estimator__max_depth=1, final_estimator__n_estimators=25;, score=0.835 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.5, final_estimator__max_depth=1, final_estimator__n_estimators=25;, score=0.808 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.5, final_estimator__max_depth=1, final_estimator__n_estimators=25;, score=0.856 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.5, final_estimator__max_depth=1, final_estimator__n_estimators=25;, score=0.808 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.5, final_estimator__max_depth=1, final_estimator__n_estimators=25;, score=0.832 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.5, final_estimator__max_depth=1, final_estimator__n_estimators=50;, score=0.863 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.5, final_estimator__max_depth=1, final_estimator__n_estimators=50;, score=0.833 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.5, final_estimator__max_depth=1, final_estimator__n_estimators=50;, score=0.873 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.5, final_estimator__max_depth=1, final_estimator__n_estimators=50;, score=0.828 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.5, final_estimator__max_depth=1, final_estimator__n_estimators=50;, score=0.854 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.5, final_estimator__max_depth=3, final_estimator__n_estimators=25;, score=0.898 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.5, final_estimator__max_depth=3, final_estimator__n_estimators=25;, score=0.874 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.5, final_estimator__max_depth=3, final_estimator__n_estimators=25;, score=0.891 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.5, final_estimator__max_depth=3, final_estimator__n_estimators=25;, score=0.857 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.5, final_estimator__max_depth=3, final_estimator__n_estimators=25;, score=0.866 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.5, final_estimator__max_depth=3, final_estimator__n_estimators=50;, score=0.910 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.5, final_estimator__max_depth=3, final_estimator__n_estimators=50;, score=0.880 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.5, final_estimator__max_depth=3, final_estimator__n_estimators=50;, score=0.903 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.5, final_estimator__max_depth=3, final_estimator__n_estimators=50;, score=0.883 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.5, final_estimator__max_depth=3, final_estimator__n_estimators=50;, score=0.866 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.5, final_estimator__max_depth=5, final_estimator__n_estimators=25;, score=0.888 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.5, final_estimator__max_depth=5, final_estimator__n_estimators=25;, score=0.860 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.5, final_estimator__max_depth=5, final_estimator__n_estimators=25;, score=0.890 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.5, final_estimator__max_depth=5, final_estimator__n_estimators=25;, score=0.884 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.5, final_estimator__max_depth=5, final_estimator__n_estimators=25;, score=0.888 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.5, final_estimator__max_depth=5, final_estimator__n_estimators=50;, score=0.893 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.5, final_estimator__max_depth=5, final_estimator__n_estimators=50;, score=0.869 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.5, final_estimator__max_depth=5, final_estimator__n_estimators=50;, score=0.892 total time=   0.1s
# [CV 4/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.5, final_estimator__max_depth=5, final_estimator__n_estimators=50;, score=0.884 total time=   0.1s
# [CV 5/5] END KNN__n_neighbors=3, TREE__max_depth=None, final_estimator__learning_rate=0.5, final_estimator__max_depth=5, final_estimator__n_estimators=50;, score=0.889 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.1, final_estimator__max_depth=1, final_estimator__n_estimators=25;, score=0.671 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.1, final_estimator__max_depth=1, final_estimator__n_estimators=25;, score=0.675 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.1, final_estimator__max_depth=1, final_estimator__n_estimators=25;, score=0.679 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.1, final_estimator__max_depth=1, final_estimator__n_estimators=25;, score=0.639 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.1, final_estimator__max_depth=1, final_estimator__n_estimators=25;, score=0.695 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.1, final_estimator__max_depth=1, final_estimator__n_estimators=50;, score=0.759 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.1, final_estimator__max_depth=1, final_estimator__n_estimators=50;, score=0.761 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.1, final_estimator__max_depth=1, final_estimator__n_estimators=50;, score=0.795 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.1, final_estimator__max_depth=1, final_estimator__n_estimators=50;, score=0.749 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.1, final_estimator__max_depth=1, final_estimator__n_estimators=50;, score=0.780 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.1, final_estimator__max_depth=3, final_estimator__n_estimators=25;, score=0.822 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.1, final_estimator__max_depth=3, final_estimator__n_estimators=25;, score=0.819 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.1, final_estimator__max_depth=3, final_estimator__n_estimators=25;, score=0.846 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.1, final_estimator__max_depth=3, final_estimator__n_estimators=25;, score=0.808 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.1, final_estimator__max_depth=3, final_estimator__n_estimators=25;, score=0.830 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.1, final_estimator__max_depth=3, final_estimator__n_estimators=50;, score=0.871 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.1, final_estimator__max_depth=3, final_estimator__n_estimators=50;, score=0.861 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.1, final_estimator__max_depth=3, final_estimator__n_estimators=50;, score=0.880 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.1, final_estimator__max_depth=3, final_estimator__n_estimators=50;, score=0.874 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.1, final_estimator__max_depth=3, final_estimator__n_estimators=50;, score=0.878 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.1, final_estimator__max_depth=5, final_estimator__n_estimators=25;, score=0.861 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.1, final_estimator__max_depth=5, final_estimator__n_estimators=25;, score=0.857 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.1, final_estimator__max_depth=5, final_estimator__n_estimators=25;, score=0.861 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.1, final_estimator__max_depth=5, final_estimator__n_estimators=25;, score=0.849 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.1, final_estimator__max_depth=5, final_estimator__n_estimators=25;, score=0.878 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.1, final_estimator__max_depth=5, final_estimator__n_estimators=50;, score=0.893 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.1, final_estimator__max_depth=5, final_estimator__n_estimators=50;, score=0.889 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.1, final_estimator__max_depth=5, final_estimator__n_estimators=50;, score=0.898 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.1, final_estimator__max_depth=5, final_estimator__n_estimators=50;, score=0.895 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.1, final_estimator__max_depth=5, final_estimator__n_estimators=50;, score=0.910 total time=   0.1s
# [CV 1/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.3, final_estimator__max_depth=1, final_estimator__n_estimators=25;, score=0.788 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.3, final_estimator__max_depth=1, final_estimator__n_estimators=25;, score=0.798 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.3, final_estimator__max_depth=1, final_estimator__n_estimators=25;, score=0.825 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.3, final_estimator__max_depth=1, final_estimator__n_estimators=25;, score=0.794 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.3, final_estimator__max_depth=1, final_estimator__n_estimators=25;, score=0.809 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.3, final_estimator__max_depth=1, final_estimator__n_estimators=50;, score=0.823 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.3, final_estimator__max_depth=1, final_estimator__n_estimators=50;, score=0.823 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.3, final_estimator__max_depth=1, final_estimator__n_estimators=50;, score=0.851 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.3, final_estimator__max_depth=1, final_estimator__n_estimators=50;, score=0.829 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.3, final_estimator__max_depth=1, final_estimator__n_estimators=50;, score=0.839 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.3, final_estimator__max_depth=3, final_estimator__n_estimators=25;, score=0.869 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.3, final_estimator__max_depth=3, final_estimator__n_estimators=25;, score=0.871 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.3, final_estimator__max_depth=3, final_estimator__n_estimators=25;, score=0.888 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.3, final_estimator__max_depth=3, final_estimator__n_estimators=25;, score=0.876 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.3, final_estimator__max_depth=3, final_estimator__n_estimators=25;, score=0.883 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.3, final_estimator__max_depth=3, final_estimator__n_estimators=50;, score=0.889 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.3, final_estimator__max_depth=3, final_estimator__n_estimators=50;, score=0.884 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.3, final_estimator__max_depth=3, final_estimator__n_estimators=50;, score=0.898 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.3, final_estimator__max_depth=3, final_estimator__n_estimators=50;, score=0.894 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.3, final_estimator__max_depth=3, final_estimator__n_estimators=50;, score=0.900 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.3, final_estimator__max_depth=5, final_estimator__n_estimators=25;, score=0.901 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.3, final_estimator__max_depth=5, final_estimator__n_estimators=25;, score=0.883 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.3, final_estimator__max_depth=5, final_estimator__n_estimators=25;, score=0.903 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.3, final_estimator__max_depth=5, final_estimator__n_estimators=25;, score=0.898 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.3, final_estimator__max_depth=5, final_estimator__n_estimators=25;, score=0.909 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.3, final_estimator__max_depth=5, final_estimator__n_estimators=50;, score=0.914 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.3, final_estimator__max_depth=5, final_estimator__n_estimators=50;, score=0.882 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.3, final_estimator__max_depth=5, final_estimator__n_estimators=50;, score=0.907 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.3, final_estimator__max_depth=5, final_estimator__n_estimators=50;, score=0.906 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.3, final_estimator__max_depth=5, final_estimator__n_estimators=50;, score=0.911 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.5, final_estimator__max_depth=1, final_estimator__n_estimators=25;, score=0.795 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.5, final_estimator__max_depth=1, final_estimator__n_estimators=25;, score=0.793 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.5, final_estimator__max_depth=1, final_estimator__n_estimators=25;, score=0.833 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.5, final_estimator__max_depth=1, final_estimator__n_estimators=25;, score=0.800 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.5, final_estimator__max_depth=1, final_estimator__n_estimators=25;, score=0.805 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.5, final_estimator__max_depth=1, final_estimator__n_estimators=50;, score=0.833 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.5, final_estimator__max_depth=1, final_estimator__n_estimators=50;, score=0.827 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.5, final_estimator__max_depth=1, final_estimator__n_estimators=50;, score=0.856 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.5, final_estimator__max_depth=1, final_estimator__n_estimators=50;, score=0.834 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.5, final_estimator__max_depth=1, final_estimator__n_estimators=50;, score=0.837 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.5, final_estimator__max_depth=3, final_estimator__n_estimators=25;, score=0.876 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.5, final_estimator__max_depth=3, final_estimator__n_estimators=25;, score=0.892 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.5, final_estimator__max_depth=3, final_estimator__n_estimators=25;, score=0.891 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.5, final_estimator__max_depth=3, final_estimator__n_estimators=25;, score=0.865 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.5, final_estimator__max_depth=3, final_estimator__n_estimators=25;, score=0.889 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.5, final_estimator__max_depth=3, final_estimator__n_estimators=50;, score=0.884 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.5, final_estimator__max_depth=3, final_estimator__n_estimators=50;, score=0.898 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.5, final_estimator__max_depth=3, final_estimator__n_estimators=50;, score=0.902 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.5, final_estimator__max_depth=3, final_estimator__n_estimators=50;, score=0.875 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.5, final_estimator__max_depth=3, final_estimator__n_estimators=50;, score=0.895 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.5, final_estimator__max_depth=5, final_estimator__n_estimators=25;, score=0.884 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.5, final_estimator__max_depth=5, final_estimator__n_estimators=25;, score=0.876 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.5, final_estimator__max_depth=5, final_estimator__n_estimators=25;, score=0.885 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.5, final_estimator__max_depth=5, final_estimator__n_estimators=25;, score=0.862 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.5, final_estimator__max_depth=5, final_estimator__n_estimators=25;, score=0.899 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.5, final_estimator__max_depth=5, final_estimator__n_estimators=50;, score=0.890 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.5, final_estimator__max_depth=5, final_estimator__n_estimators=50;, score=0.883 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.5, final_estimator__max_depth=5, final_estimator__n_estimators=50;, score=0.888 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.5, final_estimator__max_depth=5, final_estimator__n_estimators=50;, score=0.870 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=3, TREE__max_depth=3, final_estimator__learning_rate=0.5, final_estimator__max_depth=5, final_estimator__n_estimators=50;, score=0.898 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.1, final_estimator__max_depth=1, final_estimator__n_estimators=25;, score=0.735 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.1, final_estimator__max_depth=1, final_estimator__n_estimators=25;, score=0.726 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.1, final_estimator__max_depth=1, final_estimator__n_estimators=25;, score=0.711 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.1, final_estimator__max_depth=1, final_estimator__n_estimators=25;, score=0.668 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.1, final_estimator__max_depth=1, final_estimator__n_estimators=25;, score=0.742 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.1, final_estimator__max_depth=1, final_estimator__n_estimators=50;, score=0.816 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.1, final_estimator__max_depth=1, final_estimator__n_estimators=50;, score=0.803 total time=   0.1s
# [CV 3/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.1, final_estimator__max_depth=1, final_estimator__n_estimators=50;, score=0.825 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.1, final_estimator__max_depth=1, final_estimator__n_estimators=50;, score=0.773 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.1, final_estimator__max_depth=1, final_estimator__n_estimators=50;, score=0.824 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.1, final_estimator__max_depth=3, final_estimator__n_estimators=25;, score=0.852 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.1, final_estimator__max_depth=3, final_estimator__n_estimators=25;, score=0.830 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.1, final_estimator__max_depth=3, final_estimator__n_estimators=25;, score=0.864 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.1, final_estimator__max_depth=3, final_estimator__n_estimators=25;, score=0.822 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.1, final_estimator__max_depth=3, final_estimator__n_estimators=25;, score=0.861 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.1, final_estimator__max_depth=3, final_estimator__n_estimators=50;, score=0.889 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.1, final_estimator__max_depth=3, final_estimator__n_estimators=50;, score=0.867 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.1, final_estimator__max_depth=3, final_estimator__n_estimators=50;, score=0.900 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.1, final_estimator__max_depth=3, final_estimator__n_estimators=50;, score=0.875 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.1, final_estimator__max_depth=3, final_estimator__n_estimators=50;, score=0.885 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.1, final_estimator__max_depth=5, final_estimator__n_estimators=25;, score=0.862 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.1, final_estimator__max_depth=5, final_estimator__n_estimators=25;, score=0.836 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.1, final_estimator__max_depth=5, final_estimator__n_estimators=25;, score=0.893 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.1, final_estimator__max_depth=5, final_estimator__n_estimators=25;, score=0.851 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.1, final_estimator__max_depth=5, final_estimator__n_estimators=25;, score=0.885 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.1, final_estimator__max_depth=5, final_estimator__n_estimators=50;, score=0.888 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.1, final_estimator__max_depth=5, final_estimator__n_estimators=50;, score=0.867 total time=   0.1s
# [CV 3/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.1, final_estimator__max_depth=5, final_estimator__n_estimators=50;, score=0.913 total time=   0.1s
# [CV 4/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.1, final_estimator__max_depth=5, final_estimator__n_estimators=50;, score=0.885 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.1, final_estimator__max_depth=5, final_estimator__n_estimators=50;, score=0.905 total time=   0.1s
# [CV 1/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.3, final_estimator__max_depth=1, final_estimator__n_estimators=25;, score=0.839 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.3, final_estimator__max_depth=1, final_estimator__n_estimators=25;, score=0.824 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.3, final_estimator__max_depth=1, final_estimator__n_estimators=25;, score=0.851 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.3, final_estimator__max_depth=1, final_estimator__n_estimators=25;, score=0.794 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.3, final_estimator__max_depth=1, final_estimator__n_estimators=25;, score=0.844 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.3, final_estimator__max_depth=1, final_estimator__n_estimators=50;, score=0.863 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.3, final_estimator__max_depth=1, final_estimator__n_estimators=50;, score=0.836 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.3, final_estimator__max_depth=1, final_estimator__n_estimators=50;, score=0.876 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.3, final_estimator__max_depth=1, final_estimator__n_estimators=50;, score=0.829 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.3, final_estimator__max_depth=1, final_estimator__n_estimators=50;, score=0.859 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.3, final_estimator__max_depth=3, final_estimator__n_estimators=25;, score=0.893 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.3, final_estimator__max_depth=3, final_estimator__n_estimators=25;, score=0.854 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.3, final_estimator__max_depth=3, final_estimator__n_estimators=25;, score=0.901 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.3, final_estimator__max_depth=3, final_estimator__n_estimators=25;, score=0.882 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.3, final_estimator__max_depth=3, final_estimator__n_estimators=25;, score=0.890 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.3, final_estimator__max_depth=3, final_estimator__n_estimators=50;, score=0.898 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.3, final_estimator__max_depth=3, final_estimator__n_estimators=50;, score=0.869 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.3, final_estimator__max_depth=3, final_estimator__n_estimators=50;, score=0.906 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.3, final_estimator__max_depth=3, final_estimator__n_estimators=50;, score=0.891 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.3, final_estimator__max_depth=3, final_estimator__n_estimators=50;, score=0.901 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.3, final_estimator__max_depth=5, final_estimator__n_estimators=25;, score=0.882 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.3, final_estimator__max_depth=5, final_estimator__n_estimators=25;, score=0.871 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.3, final_estimator__max_depth=5, final_estimator__n_estimators=25;, score=0.915 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.3, final_estimator__max_depth=5, final_estimator__n_estimators=25;, score=0.882 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.3, final_estimator__max_depth=5, final_estimator__n_estimators=25;, score=0.897 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.3, final_estimator__max_depth=5, final_estimator__n_estimators=50;, score=0.888 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.3, final_estimator__max_depth=5, final_estimator__n_estimators=50;, score=0.873 total time=   0.1s
# [CV 3/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.3, final_estimator__max_depth=5, final_estimator__n_estimators=50;, score=0.919 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.3, final_estimator__max_depth=5, final_estimator__n_estimators=50;, score=0.887 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.3, final_estimator__max_depth=5, final_estimator__n_estimators=50;, score=0.897 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.5, final_estimator__max_depth=1, final_estimator__n_estimators=25;, score=0.842 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.5, final_estimator__max_depth=1, final_estimator__n_estimators=25;, score=0.805 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.5, final_estimator__max_depth=1, final_estimator__n_estimators=25;, score=0.852 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.5, final_estimator__max_depth=1, final_estimator__n_estimators=25;, score=0.809 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.5, final_estimator__max_depth=1, final_estimator__n_estimators=25;, score=0.831 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.5, final_estimator__max_depth=1, final_estimator__n_estimators=50;, score=0.864 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.5, final_estimator__max_depth=1, final_estimator__n_estimators=50;, score=0.833 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.5, final_estimator__max_depth=1, final_estimator__n_estimators=50;, score=0.870 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.5, final_estimator__max_depth=1, final_estimator__n_estimators=50;, score=0.835 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.5, final_estimator__max_depth=1, final_estimator__n_estimators=50;, score=0.851 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.5, final_estimator__max_depth=3, final_estimator__n_estimators=25;, score=0.894 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.5, final_estimator__max_depth=3, final_estimator__n_estimators=25;, score=0.890 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.5, final_estimator__max_depth=3, final_estimator__n_estimators=25;, score=0.891 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.5, final_estimator__max_depth=3, final_estimator__n_estimators=25;, score=0.887 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.5, final_estimator__max_depth=3, final_estimator__n_estimators=25;, score=0.878 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.5, final_estimator__max_depth=3, final_estimator__n_estimators=50;, score=0.906 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=5, TREE__max_depth=None, final_estimator__learning_rate=0.5, final_estimator__max_depth=3, final_estimator__n_estimators=50;, score=0.892 total time=   0.0s
# ...
# [CV 1/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.1, final_estimator__max_depth=1, final_estimator__n_estimators=50;, score=0.758 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.1, final_estimator__max_depth=1, final_estimator__n_estimators=50;, score=0.764 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.1, final_estimator__max_depth=1, final_estimator__n_estimators=50;, score=0.804 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.1, final_estimator__max_depth=1, final_estimator__n_estimators=50;, score=0.748 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.1, final_estimator__max_depth=1, final_estimator__n_estimators=50;, score=0.783 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.1, final_estimator__max_depth=3, final_estimator__n_estimators=25;, score=0.824 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.1, final_estimator__max_depth=3, final_estimator__n_estimators=25;, score=0.819 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.1, final_estimator__max_depth=3, final_estimator__n_estimators=25;, score=0.849 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.1, final_estimator__max_depth=3, final_estimator__n_estimators=25;, score=0.822 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.1, final_estimator__max_depth=3, final_estimator__n_estimators=25;, score=0.835 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.1, final_estimator__max_depth=3, final_estimator__n_estimators=50;, score=0.864 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.1, final_estimator__max_depth=3, final_estimator__n_estimators=50;, score=0.864 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.1, final_estimator__max_depth=3, final_estimator__n_estimators=50;, score=0.886 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.1, final_estimator__max_depth=3, final_estimator__n_estimators=50;, score=0.876 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.1, final_estimator__max_depth=3, final_estimator__n_estimators=50;, score=0.880 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.1, final_estimator__max_depth=5, final_estimator__n_estimators=25;, score=0.856 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.1, final_estimator__max_depth=5, final_estimator__n_estimators=25;, score=0.851 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.1, final_estimator__max_depth=5, final_estimator__n_estimators=25;, score=0.875 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.1, final_estimator__max_depth=5, final_estimator__n_estimators=25;, score=0.847 total time=   0.1s
# [CV 5/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.1, final_estimator__max_depth=5, final_estimator__n_estimators=25;, score=0.877 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.1, final_estimator__max_depth=5, final_estimator__n_estimators=50;, score=0.886 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.1, final_estimator__max_depth=5, final_estimator__n_estimators=50;, score=0.885 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.1, final_estimator__max_depth=5, final_estimator__n_estimators=50;, score=0.908 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.1, final_estimator__max_depth=5, final_estimator__n_estimators=50;, score=0.888 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.1, final_estimator__max_depth=5, final_estimator__n_estimators=50;, score=0.910 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.3, final_estimator__max_depth=1, final_estimator__n_estimators=25;, score=0.789 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.3, final_estimator__max_depth=1, final_estimator__n_estimators=25;, score=0.798 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.3, final_estimator__max_depth=1, final_estimator__n_estimators=25;, score=0.836 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.3, final_estimator__max_depth=1, final_estimator__n_estimators=25;, score=0.792 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.3, final_estimator__max_depth=1, final_estimator__n_estimators=25;, score=0.813 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.3, final_estimator__max_depth=1, final_estimator__n_estimators=50;, score=0.822 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.3, final_estimator__max_depth=1, final_estimator__n_estimators=50;, score=0.825 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.3, final_estimator__max_depth=1, final_estimator__n_estimators=50;, score=0.858 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.3, final_estimator__max_depth=1, final_estimator__n_estimators=50;, score=0.824 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.3, final_estimator__max_depth=1, final_estimator__n_estimators=50;, score=0.837 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.3, final_estimator__max_depth=3, final_estimator__n_estimators=25;, score=0.876 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.3, final_estimator__max_depth=3, final_estimator__n_estimators=25;, score=0.875 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.3, final_estimator__max_depth=3, final_estimator__n_estimators=25;, score=0.880 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.3, final_estimator__max_depth=3, final_estimator__n_estimators=25;, score=0.878 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.3, final_estimator__max_depth=3, final_estimator__n_estimators=25;, score=0.892 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.3, final_estimator__max_depth=3, final_estimator__n_estimators=50;, score=0.898 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.3, final_estimator__max_depth=3, final_estimator__n_estimators=50;, score=0.886 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.3, final_estimator__max_depth=3, final_estimator__n_estimators=50;, score=0.899 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.3, final_estimator__max_depth=3, final_estimator__n_estimators=50;, score=0.892 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.3, final_estimator__max_depth=3, final_estimator__n_estimators=50;, score=0.912 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.3, final_estimator__max_depth=5, final_estimator__n_estimators=25;, score=0.891 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.3, final_estimator__max_depth=5, final_estimator__n_estimators=25;, score=0.895 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.3, final_estimator__max_depth=5, final_estimator__n_estimators=25;, score=0.884 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.3, final_estimator__max_depth=5, final_estimator__n_estimators=25;, score=0.875 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.3, final_estimator__max_depth=5, final_estimator__n_estimators=25;, score=0.896 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.3, final_estimator__max_depth=5, final_estimator__n_estimators=50;, score=0.900 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.3, final_estimator__max_depth=5, final_estimator__n_estimators=50;, score=0.902 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.3, final_estimator__max_depth=5, final_estimator__n_estimators=50;, score=0.892 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.3, final_estimator__max_depth=5, final_estimator__n_estimators=50;, score=0.887 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.3, final_estimator__max_depth=5, final_estimator__n_estimators=50;, score=0.904 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.5, final_estimator__max_depth=1, final_estimator__n_estimators=25;, score=0.811 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.5, final_estimator__max_depth=1, final_estimator__n_estimators=25;, score=0.804 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.5, final_estimator__max_depth=1, final_estimator__n_estimators=25;, score=0.851 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.5, final_estimator__max_depth=1, final_estimator__n_estimators=25;, score=0.793 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.5, final_estimator__max_depth=1, final_estimator__n_estimators=25;, score=0.816 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.5, final_estimator__max_depth=1, final_estimator__n_estimators=50;, score=0.834 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.5, final_estimator__max_depth=1, final_estimator__n_estimators=50;, score=0.835 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.5, final_estimator__max_depth=1, final_estimator__n_estimators=50;, score=0.871 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.5, final_estimator__max_depth=1, final_estimator__n_estimators=50;, score=0.819 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.5, final_estimator__max_depth=1, final_estimator__n_estimators=50;, score=0.840 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.5, final_estimator__max_depth=3, final_estimator__n_estimators=25;, score=0.881 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.5, final_estimator__max_depth=3, final_estimator__n_estimators=25;, score=0.876 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.5, final_estimator__max_depth=3, final_estimator__n_estimators=25;, score=0.897 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.5, final_estimator__max_depth=3, final_estimator__n_estimators=25;, score=0.863 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.5, final_estimator__max_depth=3, final_estimator__n_estimators=25;, score=0.881 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.5, final_estimator__max_depth=3, final_estimator__n_estimators=50;, score=0.904 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.5, final_estimator__max_depth=3, final_estimator__n_estimators=50;, score=0.892 total time=   0.1s
# [CV 3/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.5, final_estimator__max_depth=3, final_estimator__n_estimators=50;, score=0.903 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.5, final_estimator__max_depth=3, final_estimator__n_estimators=50;, score=0.883 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.5, final_estimator__max_depth=3, final_estimator__n_estimators=50;, score=0.879 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.5, final_estimator__max_depth=5, final_estimator__n_estimators=25;, score=0.876 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.5, final_estimator__max_depth=5, final_estimator__n_estimators=25;, score=0.891 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.5, final_estimator__max_depth=5, final_estimator__n_estimators=25;, score=0.889 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.5, final_estimator__max_depth=5, final_estimator__n_estimators=25;, score=0.883 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.5, final_estimator__max_depth=5, final_estimator__n_estimators=25;, score=0.911 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.5, final_estimator__max_depth=5, final_estimator__n_estimators=50;, score=0.879 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.5, final_estimator__max_depth=5, final_estimator__n_estimators=50;, score=0.893 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.5, final_estimator__max_depth=5, final_estimator__n_estimators=50;, score=0.892 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.5, final_estimator__max_depth=5, final_estimator__n_estimators=50;, score=0.888 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=9, TREE__max_depth=3, final_estimator__learning_rate=0.5, final_estimator__max_depth=5, final_estimator__n_estimators=50;, score=0.915 total time=   0.0s
# Best Parameters: {'KNN__n_neighbors': 5, 'TREE__max_depth': 3, 'final_estimator__learning_rate': 0.3, 'final_estimator__max_depth': 5, 'final_estimator__n_estimators': 50}
# Best Score: 0.9053454515298233
